# %% [markdown]
# # Tuberculosis

# %% [markdown]
# [Tuberculosis](https://www.who.int/health-topics/tuberculosis), or TB, is an infectious disease that can [affect](https://www.healthdirect.gov.au/tuberculosis) [any part of the body](https://www.nhsinform.scot/illnesses-and-conditions/infections-and-poisoning/tuberculosis-tb), including the glands, bones and nervous system, most often affects the lungs. TB is caused by a type of bacteria (*Mycobacterium tuberculosis*).

# %%
# Data manipulation
import numpy as np
import pandas as pd
import datetime as dt

# Data visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Matplotlib', mpl.__version__)
print('Seaborn', sns.__version__)
# Out:
# NumPy 1.23.5
# Pandas 1.5.3
# Matplotlib 3.7.1
# Seaborn 0.12.2

# %%
# Read the data files
df_19 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB2019_kepesertaan.dta')
df_20 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB2020_kepesertaan.dta')
df_21 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB2021_kepesertaan.dta')
# df_fktp_k = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB20152021_fktpkapitasi.dta', convert_categoricals=False)
df_fkrtl_1 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB20152021_fkrtl.dta')
df_fktp_nk = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB20152021_fktpnonkapitasi.dta')
df_fkrtl_2 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual TB/TB20152021_fkrtldxsekunder.dta')

# %% [markdown]
# ## 1. Hasil Data Sampel BPJS Kesehatan

# %% [markdown]
# ### 1.1. Kepesertaan BPJS Kesehatan

# %% [markdown]
# #### 1.1.1. Tahun 2019

# %%
df_19.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_19.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in TB2019_kepesertaan.dta')
df_19.head()
# Out:
# Data in TB2019_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       21611150        21611150            1957-09-12           PESERTA
# 1       94343049        96772919            1961-12-03             SUAMI
# 2       83393824       298548714            2002-10-05              ANAK
# 3      328537885       328537885            1989-07-13           PESERTA
# 4       67805935        67805935            1972-11-13           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     PEREMPUAN             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I            PPU
# 2     LAKI-LAKI       BELUM KAWIN     KELAS I            PPU
# 3     PEREMPUAN       BELUM KAWIN   KELAS III       PBI APBD
# 4     LAKI-LAKI             KAWIN     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                            ACEH BESAR
# 1                            ACEH                         ACEH TENGGARA
# 2                            ACEH                         ACEH TENGGARA
# 3                            ACEH                          ACEH TAMIANG
# 4                            ACEH                          ACEH TAMIANG
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta     Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                    ACEH BESAR  1.157796          2019              AKTIF
# 1                 ACEH TENGGARA  1.556821          2019              AKTIF
# 2                 ACEH TENGGARA  1.159913          2019              AKTIF
# 3                  ACEH TAMIANG  9.436164          2019              AKTIF
# 4                  ACEH TAMIANG  0.899331          2019              AKTIF
#
#    Tahun_Meninggal
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_19.shape
# Out:
# (94966, 18)

# %%
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nomor_Peserta                          94966 non-null  int32
#  1   Nomor_Keluarga                         94966 non-null  int32
#  2   Tanggal_Lahir_Peserta                  94966 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      94966 non-null  category
#  4   Jenis_Kelamin                          94966 non-null  category
#  5   Status_Perkawinan                      94966 non-null  category
#  6   Kelas_Rawat                            94966 non-null  category
#  7   Segmen_Peserta                         94966 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        94966 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  94966 non-null  category
#  10  Kepemilikan_Faskes                     94966 non-null  category
#  11  Jenis_Faskes                           94966 non-null  category
#  12  Provinsi_Faskes_Peserta                94966 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          94966 non-null  category
#  14  Bobot                                  94966 non-null  float32
#  15  Tahun_Sampel                           94966 non-null  int16
#  16  Status_Kepesertaan                     94966 non-null  category
#  17  Tahun_Meninggal                        4476 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
df_19.duplicated().sum()
# Out:
# 0

# %%
df_19.isna().sum().sum()
# Out:
# 90490

# %%
df_19.isna().sum()
# Out:
# Nomor_Peserta                                0
# Nomor_Keluarga                               0
# Tanggal_Lahir_Peserta                        0
# Hubungan_Keluarga                            0
# Jenis_Kelamin                                0
# Status_Perkawinan                            0
# Kelas_Rawat                                  0
# Segmen_Peserta                               0
# Provinsi_Tempat_Tinggal_Peserta              0
# Kabupaten_Kota_Tempat_Tinggal_Peserta        0
# Kepemilikan_Faskes                           0
# Jenis_Faskes                                 0
# Provinsi_Faskes_Peserta                      0
# Kabupaten_Kota_Faskes_Peserta                0
# Bobot                                        0
# Tahun_Sampel                                 0
# Status_Kepesertaan                           0
# Tahun_Meninggal                          90490
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 90.490.

# %%
df_19['Tahun_Meninggal'] = df_19['Tahun_Meninggal'].fillna(0).astype(int)
df_19['Tahun_Lahir'] = df_19['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_19['Tahun_Meninggal'] != 0,
                df_19['Tahun_Meninggal'] - df_19['Tahun_Lahir'],
                df_19['Tahun_Sampel'] - df_19['Tahun_Lahir'])
df_19['Umur'] = umur.astype(int)

# %%
df_19.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       21611150        21611150            1957-09-12           PESERTA
# 1       94343049        96772919            1961-12-03             SUAMI
# 2       83393824       298548714            2002-10-05              ANAK
# 3      328537885       328537885            1989-07-13           PESERTA
# 4       67805935        67805935            1972-11-13           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     PEREMPUAN             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I            PPU
# 2     LAKI-LAKI       BELUM KAWIN     KELAS I            PPU
# 3     PEREMPUAN       BELUM KAWIN   KELAS III       PBI APBD
# 4     LAKI-LAKI             KAWIN     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                            ACEH BESAR
# 1                            ACEH                         ACEH TENGGARA
# 2                            ACEH                         ACEH TENGGARA
# 3                            ACEH                          ACEH TAMIANG
# 4                            ACEH                          ACEH TAMIANG
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta     Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                    ACEH BESAR  1.157796          2019              AKTIF
# 1                 ACEH TENGGARA  1.556821          2019              AKTIF
# 2                 ACEH TENGGARA  1.159913          2019              AKTIF
# 3                  ACEH TAMIANG  9.436164          2019              AKTIF
# 4                  ACEH TAMIANG  0.899331          2019              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0                0         1957    62
# 1                0         1961    58
# 2                0         2002    17
# 3                0         1989    30
# 4                0         1972    47

# %%
df_19.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    9.496600e+04    9.496600e+04                 94966             94966
# unique            NaN             NaN                 26362                 5
# top               NaN             NaN   1960-07-01 00:00:00           PESERTA
# freq              NaN             NaN                   171             45375
# first             NaN             NaN   1912-12-30 00:00:00               NaN
# last              NaN             NaN   2019-07-19 00:00:00               NaN
# mean     1.830281e+08    1.903269e+08                   NaN               NaN
# std      1.597607e+08    1.607588e+08                   NaN               NaN
# min      1.394000e+03    3.687000e+03                   NaN               NaN
# 25%      4.366800e+07    4.563971e+07                   NaN               NaN
# 50%      8.745586e+07    9.109761e+07                   NaN               NaN
# 75%      3.455679e+08    3.518411e+08                   NaN               NaN
# max      4.553809e+08    4.553826e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count          94966             94966       94966          94966
# unique             2                 3           3              5
# top        LAKI-LAKI             KAWIN   KELAS III            PPU
# freq           50610             52192       55572          28232
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                            94966                                 94966
# unique                              35                                   515
# top                         JAWA TIMUR                                 BOGOR
# freq                              9479                                   390
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        68772        68890                    9473
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta         Bobot  Tahun_Sampel  \
# count                          94966  94966.000000       94966.0
# unique                           514           NaN           NaN
# top                       KOTA MEDAN           NaN           NaN
# freq                             346           NaN           NaN
# first                            NaN           NaN           NaN
# last                             NaN           NaN           NaN
# mean                             NaN      8.461007        2019.0
# std                              NaN     19.109184           0.0
# min                              NaN      0.156804        2019.0
# 25%                              NaN      1.154869        2019.0
# 50%                              NaN      2.845975        2019.0
# 75%                              NaN      7.727345        2019.0
# max                              NaN    365.923492        2019.0
#
#        Status_Kepesertaan  Tahun_Meninggal   Tahun_Lahir          Umur
# count               94966     94966.000000  94966.000000  94966.000000
# unique                  3              NaN           NaN           NaN
# top                 AKTIF              NaN           NaN           NaN
# freq                85515              NaN           NaN           NaN
# first                 NaN              NaN           NaN           NaN
# last                  NaN              NaN           NaN           NaN
# mean                  NaN        95.160837   1981.904819     37.095181
# std                   NaN       427.873897     21.737231     21.737231
# min                   NaN         0.000000   1912.000000      0.000000
# 25%                   NaN         0.000000   1964.000000     20.000000
# 50%                   NaN         0.000000   1982.000000     37.000000
# 75%                   NaN         0.000000   1999.000000     55.000000
# max                   NaN      2019.000000   2019.000000    107.000000

# %% [markdown]
# #### 1.1.2. Tahun 2020

# %%
df_20.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_20.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in TB2020_kepesertaan.dta')
df_20.head()
# Out:
# Data in TB2020_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       32853965        31945523            1958-11-27             SUAMI
# 1        8555967         8555967            1936-07-01           PESERTA
# 2        8797049          249479            1950-07-21             SUAMI
# 3       83472658        54408870            2012-08-12              ANAK
# 4      425874326       296852327            2004-12-30              ANAK
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN       BELUM KAWIN     KELAS I            PPU
# 4     LAKI-LAKI       BELUM KAWIN    KELAS II            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                           ACEH TENGAH
# 1                            ACEH                           ACEH TENGAH
# 2                            ACEH                          ACEH SELATAN
# 3                            ACEH                            ACEH BARAT
# 4                  SUMATERA UTARA                          TOBA SAMOSIR
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH   1.531137          2020          MENINGGAL
# 1                       BIREUEN   0.998777          2020              AKTIF
# 2                  ACEH SELATAN  30.096481          2020        TIDAK AKTIF
# 3                    ACEH BARAT   9.837102          2020              AKTIF
# 4                  TOBA SAMOSIR   1.038886          2020              AKTIF
#
#    Tahun_Meninggal
# 0           2020.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_20.shape
# Out:
# (94966, 18)

# %%
df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nomor_Peserta                          94966 non-null  int32
#  1   Nomor_Keluarga                         94966 non-null  int32
#  2   Tanggal_Lahir_Peserta                  94966 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      94966 non-null  category
#  4   Jenis_Kelamin                          94966 non-null  category
#  5   Status_Perkawinan                      94966 non-null  category
#  6   Kelas_Rawat                            94966 non-null  category
#  7   Segmen_Peserta                         94966 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        94966 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  94966 non-null  category
#  10  Kepemilikan_Faskes                     94966 non-null  category
#  11  Jenis_Faskes                           94966 non-null  category
#  12  Provinsi_Faskes_Peserta                94966 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          94966 non-null  category
#  14  Bobot                                  94966 non-null  float32
#  15  Tahun_Sampel                           94966 non-null  int16
#  16  Status_Kepesertaan                     94966 non-null  category
#  17  Tahun_Meninggal                        7147 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
df_20.duplicated().sum()
# Out:
# 0

# %%
df_20.isna().sum().sum()
# Out:
# 87819

# %%
df_20.isna().sum()
# Out:
# Nomor_Peserta                                0
# Nomor_Keluarga                               0
# Tanggal_Lahir_Peserta                        0
# Hubungan_Keluarga                            0
# Jenis_Kelamin                                0
# Status_Perkawinan                            0
# Kelas_Rawat                                  0
# Segmen_Peserta                               0
# Provinsi_Tempat_Tinggal_Peserta              0
# Kabupaten_Kota_Tempat_Tinggal_Peserta        0
# Kepemilikan_Faskes                           0
# Jenis_Faskes                                 0
# Provinsi_Faskes_Peserta                      0
# Kabupaten_Kota_Faskes_Peserta                0
# Bobot                                        0
# Tahun_Sampel                                 0
# Status_Kepesertaan                           0
# Tahun_Meninggal                          87819
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 87.819.

# %%
df_20['Tahun_Meninggal'] = df_20['Tahun_Meninggal'].fillna(0).astype(int)
df_20['Tahun_Lahir'] = df_20['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_20['Tahun_Meninggal'] != 0,
                df_20['Tahun_Meninggal'] - df_20['Tahun_Lahir'],
                df_20['Tahun_Sampel'] - df_20['Tahun_Lahir'])
df_20['Umur'] = umur.astype(int)

# %%
df_20.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       32853965        31945523            1958-11-27             SUAMI
# 1        8555967         8555967            1936-07-01           PESERTA
# 2        8797049          249479            1950-07-21             SUAMI
# 3       83472658        54408870            2012-08-12              ANAK
# 4      425874326       296852327            2004-12-30              ANAK
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN       BELUM KAWIN     KELAS I            PPU
# 4     LAKI-LAKI       BELUM KAWIN    KELAS II            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                           ACEH TENGAH
# 1                            ACEH                           ACEH TENGAH
# 2                            ACEH                          ACEH SELATAN
# 3                            ACEH                            ACEH BARAT
# 4                  SUMATERA UTARA                          TOBA SAMOSIR
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH   1.531137          2020          MENINGGAL
# 1                       BIREUEN   0.998777          2020              AKTIF
# 2                  ACEH SELATAN  30.096481          2020        TIDAK AKTIF
# 3                    ACEH BARAT   9.837102          2020              AKTIF
# 4                  TOBA SAMOSIR   1.038886          2020              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0             2020         1958    62
# 1                0         1936    84
# 2                0         1950    70
# 3                0         2012     8
# 4                0         2004    16

# %%
df_20.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    9.496600e+04    9.496600e+04                 94966             94966
# unique            NaN             NaN                 26362                 5
# top               NaN             NaN   1960-07-01 00:00:00           PESERTA
# freq              NaN             NaN                   171             46045
# first             NaN             NaN   1912-12-30 00:00:00               NaN
# last              NaN             NaN   2019-07-19 00:00:00               NaN
# mean     1.830281e+08    1.903269e+08                   NaN               NaN
# std      1.597607e+08    1.607588e+08                   NaN               NaN
# min      1.394000e+03    3.687000e+03                   NaN               NaN
# 25%      4.366800e+07    4.563971e+07                   NaN               NaN
# 50%      8.745586e+07    9.109761e+07                   NaN               NaN
# 75%      3.455679e+08    3.518411e+08                   NaN               NaN
# max      4.553809e+08    4.553826e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count          94966             94966       94966          94966
# unique             2                 3           4              6
# top        LAKI-LAKI             KAWIN   KELAS III            PPU
# freq           50610             52489       57629          28177
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                            94966                                 94966
# unique                              35                                   515
# top                         JAWA TIMUR                                 BOGOR
# freq                              9492                                   382
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        68772        68890                    9473
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta         Bobot  Tahun_Sampel  \
# count                          94966  94966.000000       94966.0
# unique                           514           NaN           NaN
# top                       KOTA MEDAN           NaN           NaN
# freq                             346           NaN           NaN
# first                            NaN           NaN           NaN
# last                             NaN           NaN           NaN
# mean                             NaN      8.461007        2020.0
# std                              NaN     19.109184           0.0
# min                              NaN      0.156804        2020.0
# 25%                              NaN      1.154869        2020.0
# 50%                              NaN      2.845975        2020.0
# 75%                              NaN      7.727345        2020.0
# max                              NaN    365.923492        2020.0
#
#        Status_Kepesertaan  Tahun_Meninggal   Tahun_Lahir          Umur
# count               94966     94966.000000  94966.000000  94966.000000
# unique                  3              NaN           NaN           NaN
# top                 AKTIF              NaN           NaN           NaN
# freq                75608              NaN           NaN           NaN
# first                 NaN              NaN           NaN           NaN
# last                  NaN              NaN           NaN           NaN
# mean                  NaN       151.974812   1981.904819     38.047796
# std                   NaN       532.728912     21.737231     21.708006
# min                   NaN         0.000000   1912.000000      0.000000
# 25%                   NaN         0.000000   1964.000000     21.000000
# 50%                   NaN         0.000000   1982.000000     38.000000
# 75%                   NaN         0.000000   1999.000000     56.000000
# max                   NaN      2020.000000   2019.000000    107.000000

# %% [markdown]
# #### 1.1.3. Tahun 2021

# %%
df_21.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_21.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in TB2021_kepesertaan.dta')
df_21.head()
# Out:
# Data in TB2021_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       32853965        31945523            1958-11-27             SUAMI
# 1        8555967         8555967            1936-07-01           PESERTA
# 2        8797049          249479            1950-07-21             SUAMI
# 3       83472658        54408870            2012-08-12              ANAK
# 4      425874326       296852327            2004-12-30              ANAK
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN       BELUM KAWIN     KELAS I            PPU
# 4     LAKI-LAKI       BELUM KAWIN    KELAS II            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                           ACEH TENGAH
# 1                            ACEH                           ACEH TENGAH
# 2                            ACEH                          ACEH SELATAN
# 3                            ACEH                            ACEH BARAT
# 4                  SUMATERA UTARA                          TOBA SAMOSIR
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH   1.531137          2021          MENINGGAL
# 1                       BIREUEN   0.998777          2021              AKTIF
# 2                  ACEH SELATAN  30.096481          2021        TIDAK AKTIF
# 3                    ACEH BARAT   9.837102          2021              AKTIF
# 4                  TOBA SAMOSIR   1.038886          2021              AKTIF
#
#    Tahun_Meninggal
# 0           2020.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_21.shape
# Out:
# (94966, 18)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Nomor_Peserta                          94966 non-null  int32
#  1   Nomor_Keluarga                         94966 non-null  int32
#  2   Tanggal_Lahir_Peserta                  94966 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      94966 non-null  category
#  4   Jenis_Kelamin                          94966 non-null  category
#  5   Status_Perkawinan                      94966 non-null  category
#  6   Kelas_Rawat                            94966 non-null  category
#  7   Segmen_Peserta                         94966 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        94966 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  94966 non-null  category
#  10  Kepemilikan_Faskes                     94966 non-null  category
#  11  Jenis_Faskes                           94966 non-null  category
#  12  Provinsi_Faskes_Peserta                94966 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          94966 non-null  category
#  14  Bobot                                  94966 non-null  float32
#  15  Tahun_Sampel                           94966 non-null  int16
#  16  Status_Kepesertaan                     94966 non-null  category
#  17  Tahun_Meninggal                        8654 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 4.8 MB

# %%
df_21.duplicated().sum()
# Out:
# 0

# %%
df_21.isna().sum().sum()
# Out:
# 86312

# %%
df_21.isna().sum()
# Out:
# Nomor_Peserta                                0
# Nomor_Keluarga                               0
# Tanggal_Lahir_Peserta                        0
# Hubungan_Keluarga                            0
# Jenis_Kelamin                                0
# Status_Perkawinan                            0
# Kelas_Rawat                                  0
# Segmen_Peserta                               0
# Provinsi_Tempat_Tinggal_Peserta              0
# Kabupaten_Kota_Tempat_Tinggal_Peserta        0
# Kepemilikan_Faskes                           0
# Jenis_Faskes                                 0
# Provinsi_Faskes_Peserta                      0
# Kabupaten_Kota_Faskes_Peserta                0
# Bobot                                        0
# Tahun_Sampel                                 0
# Status_Kepesertaan                           0
# Tahun_Meninggal                          86312
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 86.312.

# %%
df_21['Tahun_Meninggal'] = df_21['Tahun_Meninggal'].fillna(0).astype(int)
df_21['Tahun_Lahir'] = df_21['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_21['Tahun_Meninggal'] != 0,
                df_21['Tahun_Meninggal'] - df_21['Tahun_Lahir'],
                df_21['Tahun_Sampel'] - df_21['Tahun_Lahir'])
df_21['Umur'] = umur.astype(int)

# %%
df_21.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       32853965        31945523            1958-11-27             SUAMI
# 1        8555967         8555967            1936-07-01           PESERTA
# 2        8797049          249479            1950-07-21             SUAMI
# 3       83472658        54408870            2012-08-12              ANAK
# 4      425874326       296852327            2004-12-30              ANAK
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN       BELUM KAWIN     KELAS I            PPU
# 4     LAKI-LAKI       BELUM KAWIN    KELAS II            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                           ACEH TENGAH
# 1                            ACEH                           ACEH TENGAH
# 2                            ACEH                          ACEH SELATAN
# 3                            ACEH                            ACEH BARAT
# 4                  SUMATERA UTARA                          TOBA SAMOSIR
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH   1.531137          2021          MENINGGAL
# 1                       BIREUEN   0.998777          2021              AKTIF
# 2                  ACEH SELATAN  30.096481          2021        TIDAK AKTIF
# 3                    ACEH BARAT   9.837102          2021              AKTIF
# 4                  TOBA SAMOSIR   1.038886          2021              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0             2020         1958    62
# 1                0         1936    85
# 2                0         1950    71
# 3                0         2012     9
# 4                0         2004    17

# %%
df_21.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    9.496600e+04    9.496600e+04                 94966             94966
# unique            NaN             NaN                 26362                 5
# top               NaN             NaN   1960-07-01 00:00:00           PESERTA
# freq              NaN             NaN                   171             46915
# first             NaN             NaN   1912-12-30 00:00:00               NaN
# last              NaN             NaN   2019-07-19 00:00:00               NaN
# mean     1.830281e+08    1.903269e+08                   NaN               NaN
# std      1.597607e+08    1.607588e+08                   NaN               NaN
# min      1.394000e+03    3.687000e+03                   NaN               NaN
# 25%      4.366800e+07    4.563971e+07                   NaN               NaN
# 50%      8.745586e+07    9.109761e+07                   NaN               NaN
# 75%      3.455679e+08    3.518411e+08                   NaN               NaN
# max      4.553809e+08    4.553826e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count          94966             94966       94966          94966
# unique             2                 3           4              6
# top        LAKI-LAKI             KAWIN   KELAS III            PPU
# freq           50610             53023       57594          28408
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                            94966                                 94966
# unique                              35                                   515
# top                         JAWA TIMUR                                 BOGOR
# freq                              9495                                   382
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        69160        69282                    9514
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta         Bobot  Tahun_Sampel  \
# count                          94966  94966.000000       94966.0
# unique                           514           NaN           NaN
# top                       KOTA MEDAN           NaN           NaN
# freq                             409           NaN           NaN
# first                            NaN           NaN           NaN
# last                             NaN           NaN           NaN
# mean                             NaN      8.461007        2021.0
# std                              NaN     19.109184           0.0
# min                              NaN      0.156804        2021.0
# 25%                              NaN      1.154869        2021.0
# 50%                              NaN      2.845975        2021.0
# 75%                              NaN      7.727345        2021.0
# max                              NaN    365.923492        2021.0
#
#        Status_Kepesertaan  Tahun_Meninggal   Tahun_Lahir          Umur
# count               94966     94966.000000  94966.000000  94966.000000
# unique                  4              NaN           NaN           NaN
# top                 AKTIF              NaN           NaN           NaN
# freq                69686              NaN           NaN           NaN
# first                 NaN              NaN           NaN           NaN
# last                  NaN              NaN           NaN           NaN
# mean                  NaN       184.045932   1981.904819     38.972738
# std                   NaN       581.240260     21.737231     21.663097
# min                   NaN         0.000000   1912.000000      0.000000
# 25%                   NaN         0.000000   1964.000000     22.000000
# 50%                   NaN         0.000000   1982.000000     39.000000
# 75%                   NaN         0.000000   1999.000000     57.000000
# max                   NaN      2021.000000   2019.000000    107.000000

# %% [markdown]
# ### 1.2. Fasilitas Kesehatan Rujukan Tingkat Lanjutan (FKRTL) Diagnosis Primer

# %%
df_fkrtl_1.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48'],
#       dtype='object')

# %%
df_fkrtl_1.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'FKP02' : 'ID_Kunjungan_FKTP',
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL03' : 'Tanggal_Datang_Kunjungan',
    'FKL04' : 'Tanggal_Pulang_Kunjungan',
    'FKL05' : 'Provinsi',
    'FKL06' : 'Kabupaten_Kota',
    'FKL07' : 'Kepemilikan',
    'FKL08' : 'Jenis',
    'FKL09' : 'Tipe',
    'FKL10' : 'Tingkat_Pelayanan',
    'FKL11' : 'Jenis_Poli',
    'FKL12' : 'Segmen_Peserta_Akses_Layanan',
    'FKL13' : 'Kelas_Rawat_Peserta',
    'FKL14' : 'Status_Pulang',
    'FKL15' : 'Kode_Nama_Diagnosis_Masuk_ICD_10',
    'FKL15A': 'Kode_Diagnosis_Masuk_ICD_10',
    'FKL16' : 'Kode_ICD_10_Diagnosis_Masuk',
    'FKL16A': 'Nama_Diagnosis_Masuk',
    'FKL17' : 'Kode_Nama_Diagnosis_Primer_ICD_10',
    'FKL17A': 'Kode_Diagnosis_Primer_ICD_10',
    'FKL18' : 'Kode_ICD_10_Diagnosis_Primer',
    'FKL18A': 'Nama_Diagnosis_Primer',
    'FKL19' : 'Kode_INACBGs',
    'FKL19A': 'Deskripsi_Kode_INACBGs',
    'FKL20' : 'INACBGs_Kode_Casemix_Main_Groups',
    'FKL21' : 'INACBGs_Tipe_Kelompok_Kasus',
    'FKL22' : 'INACBGs_Spesifikasi_Kelompok_Kasus',
    'FKL23' : 'INACBGs_Tingkat_Keparahan_Kelompok_Kasus',
    'FKL25' : 'Provinsi_Faskes_Perujuk',
    'FKL26' : 'Kabupaten_Kota_Faskes_Perujuk',
    'FKL27' : 'Kepemilikan_Faskes_Perujuk',
    'FKL28' : 'Jenis_Faskes_Perujuk',
    'FKL29' : 'Tipe_Faskes_Perujuk',
    'FKL30' : 'Jenis_Prosedur',
    'FKL31' : 'Tarif_Regional_INACBGs',
    'FKL32' : 'Group_Tarif_INACBGs',
    'FKL33' : 'Kode_Special_Sub-Acute_Groups_SA',
    'FKL34' : 'Tarif_Special_Sub-Acute_Groups_SA',
    'FKL35' : 'Kode_Special_Procedures_SP',
    'FKL36' : 'Deskripsi_Special_Procedures_SP',
    'FKL37' : 'Tarif_Special_Procedures_SP',
    'FKL38' : 'Kode_Special_Prosthesis_RR',
    'FKL39' : 'Deskripsi_Special_Prosthesis_RR',
    'FKL40' : 'Tarif_Special_Prosthesis_RR',
    'FKL41' : 'Kode_Special_Investigation_SI',
    'FKL42' : 'Deskripsi_Special_Investigation_SI',
    'FKL43' : 'Tarif_Special_Investigation_SI',
    'FKL44' : 'Kode_Special_Drugs_SD',
    'FKL45' : 'Deskripsi_Special_Drugs_SD',
    'FKL46' : 'Tarif_Special_Drugs_SD',
    'FKL47' : 'Biaya_Tagih_Faskes_Provider',
    'FKL48' : 'Biaya_Verifikasi'
}, inplace=True)

# %%
df_fkrtl_1.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga     Bobot ID_Kunjungan_FKTP  \
# 0       96934726        96934726  0.899331
# 1       11315168        11315168  0.938273
# 2       48014275        20325942  0.998232
# 3       78552717         3459550  1.205653
# 4       48014275        20325942  0.998232
#
#   ID_Kunjungan_FKRTL Tanggal_Datang_Kunjungan Tanggal_Pulang_Kunjungan  \
# 0   1000801150000582               2015-01-21               2015-01-21
# 1   1000801150001076               2015-01-13               2015-01-13
# 2   1000801160000002               2016-01-02               2016-01-06
# 3   1000801160000219               2016-01-08               2016-01-08
# 4   1000801160000321               2016-01-11               2016-01-11
#
#   Provinsi Kabupaten_Kota          Kepemilikan        Jenis        Tipe  \
# 0    PAPUA       JAYAPURA  Pemerintah kab/kota  Rumah sakit  RS Kelas C
# 1    PAPUA       JAYAPURA  Pemerintah kab/kota  Rumah sakit  RS Kelas C
# 2    PAPUA       JAYAPURA  Pemerintah kab/kota  Rumah sakit  RS Kelas C
# 3    PAPUA       JAYAPURA  Pemerintah kab/kota  Rumah sakit  RS Kelas C
# 4    PAPUA       JAYAPURA  Pemerintah kab/kota  Rumah sakit  RS Kelas C
#
#   Tingkat_Pelayanan Jenis_Poli Segmen_Peserta_Akses_Layanan  \
# 0              RJTL        INT                          PPU
# 1              RJTL        UGD                          PPU
# 2              RITL    Missing                     PBI APBN
# 3              RJTL        GIG                         PBPU
# 4              RJTL        BED                     PBI APBN
#
#   Kelas_Rawat_Peserta Status_Pulang  \
# 0             Kelas 3         Sehat
# 1             Kelas 3         Sehat
# 2             Kelas 3         Sehat
# 3             Kelas 3         Sehat
# 4             Kelas 3         Sehat
#
#                     Kode_Nama_Diagnosis_Masuk_ICD_10  \
# 0  Z09 Follow-up examination after treatment for ...
# 1                               J20 Acute bronchitis
# 2              T14 Injury of unspecified body region
# 3        K04 Diseases of pulp and periapical tissues
# 4  Z09 Follow-up examination after treatment for ...
#
#   Kode_Diagnosis_Masuk_ICD_10 Kode_ICD_10_Diagnosis_Masuk  \
# 0                         Z09                        Z098
# 1                         J20                        J209
# 2                         T14                        T141
# 3                         K04                        K041
# 4                         Z09                        Z098
#
#                                 Nama_Diagnosis_Masuk  \
# 0  Follow-up examination after other treatment fo...
# 1                      Acute bronchitis, unspecified
# 2              Open wound of unspecified body region
# 3                                   Necrosis of pulp
# 4  Follow-up examination after other treatment fo...
#
#                    Kode_Nama_Diagnosis_Primer_ICD_10  \
# 0                       E11 Type 2 diabetes mellitus
# 1  J40 Bronchitis, not specified as acute or chronic
# 2    T01 Open wounds involving multiple body regions
# 3                                  K02 Dental caries
# 4  Z09 Follow-up examination after treatment for ...
#
#   Kode_Diagnosis_Primer_ICD_10 Kode_ICD_10_Diagnosis_Primer  \
# 0                          E11                         E119
# 1                          J40                          J40
# 2                          T01                         T019
# 3                          K02                         K020
# 4                          Z09                         Z098
#
#                                Nama_Diagnosis_Primer Kode_INACBGs  \
# 0  Non-insulin-dependent diabetes mellitus withou...     Q-5-44-0
# 1      Bronchitis, not specified as acute or chronic     J-3-13-0
# 2                  Multiple open wounds, unspecified     L-4-13-I
# 3                           Caries limited to enamel     Q-5-12-0
# 4  Follow-up examination after other treatment fo...     Q-5-44-0
#
#                               Deskripsi_Kode_INACBGs  \
# 0                    PENYAKIT KRONIS KECIL LAIN-LAIN
# 1                 PROSEDUR TERAPI SALURAN PERNAFASAN
# 2  TRAUMA PADA KULIT, JARINGAN BAWAH KULIT DAN PA...
# 3                                               GIGI
# 4                    PENYAKIT KRONIS KECIL LAIN-LAIN
#
#           INACBGs_Kode_Casemix_Main_Groups      INACBGs_Tipe_Kelompok_Kasus  \
# 0            Q. Ambulatory Groups-Episodic       Rawat Jalan Bukan Prosedur
# 1             J. Respiratory system Groups  Prosedur Signifikan Rawat Jalan
# 2  L. Skin, subcutaneous tissue & breast G        Rawat Inap Bukan Prosedur
# 3            Q. Ambulatory Groups-Episodic       Rawat Jalan Bukan Prosedur
# 4            Q. Ambulatory Groups-Episodic       Rawat Jalan Bukan Prosedur
#
#    INACBGs_Spesifikasi_Kelompok_Kasus  \
# 0                                  44
# 1                                  13
# 2                                  13
# 3                                  12
# 4                                  44
#
#   INACBGs_Tingkat_Keparahan_Kelompok_Kasus Provinsi_Faskes_Perujuk  \
# 0                              Rawat Jalan                   PAPUA
# 1                              Rawat Jalan                   PAPUA
# 2          Ringan (rawat inap keparahan 1)           TIDAK DIRUJUK
# 3                              Rawat Jalan                   PAPUA
# 4                              Rawat Jalan                   PAPUA
#
#   Kabupaten_Kota_Faskes_Perujuk Kepemilikan_Faskes_Perujuk  \
# 0                      JAYAPURA                     PemKab
# 1                      JAYAPURA                     Swasta
# 2                 TIDAK DIRUJUK              BUKAN RUJUKAN
# 3                      JAYAPURA                     PemKab
# 4                         SARMI                     PemKab
#
#   Jenis_Faskes_Perujuk        Tipe_Faskes_Perujuk Jenis_Prosedur  \
# 0            Puskesmas             NON RAWAT INAP
# 1          Dokter Umum  DOKTER PRAKTER PERORANGAN
# 2        BUKAN RUJUKAN              BUKAN RUJUKAN
# 3            Puskesmas                 RAWAT INAP
# 4            Puskesmas                 RAWAT INAP
#
#   Tarif_Regional_INACBGs  Group_Tarif_INACBGs  \
# 0             regional 5               166300
# 1             regional 5               255200
# 2             regional 5              1515300
# 3             regional 5               128600
# 4             regional 5               166300
#
#   Kode_Special_Sub-Acute_Groups_SA  Tarif_Special_Sub-Acute_Groups_SA  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 0.0
# 3                                                                 0.0
# 4                                                                 0.0
#
#   Kode_Special_Procedures_SP Deskripsi_Special_Procedures_SP  \
# 0
# 1
# 2
# 3
# 4
#
#    Tarif_Special_Procedures_SP Kode_Special_Prosthesis_RR  \
# 0                          NaN
# 1                          NaN
# 2                          0.0
# 3                          0.0
# 4                          0.0
#
#   Deskripsi_Special_Prosthesis_RR  Tarif_Special_Prosthesis_RR  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          0.0
# 3                                                          0.0
# 4                                                          0.0
#
#   Kode_Special_Investigation_SI Deskripsi_Special_Investigation_SI  \
# 0
# 1
# 2
# 3
# 4
#
#    Tarif_Special_Investigation_SI Kode_Special_Drugs_SD  \
# 0                             NaN
# 1                             NaN
# 2                             0.0
# 3                             0.0
# 4                             0.0
#
#   Deskripsi_Special_Drugs_SD  Tarif_Special_Drugs_SD  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#    Biaya_Tagih_Faskes_Provider  Biaya_Verifikasi
# 0                       166300            166300
# 1                       255200            255200
# 2                      1515300           1515300
# 3                       128600            128600
# 4                       166300            166300

# %%
df_fkrtl_1.shape
# Out:
# (1583242, 55)

# %%
df_fkrtl_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1583242 entries, 0 to 1583241
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   Nomor_Peserta                             1583242 non-null  int32
#  1   Nomor_Keluarga                            1583242 non-null  int32
#  2   Bobot                                     1583242 non-null  float32
#  3   ID_Kunjungan_FKTP                         1583242 non-null  object
#  4   ID_Kunjungan_FKRTL                        1583242 non-null  object
#  5   Tanggal_Datang_Kunjungan                  1583242 non-null  datetime64[ns]
#  6   Tanggal_Pulang_Kunjungan                  1583242 non-null  datetime64[ns]
#  7   Provinsi                                  1583242 non-null  category
#  8   Kabupaten_Kota                            1583242 non-null  category
#  9   Kepemilikan                               1583242 non-null  category
#  10  Jenis                                     1583242 non-null  category
#  11  Tipe                                      1583242 non-null  category
#  12  Tingkat_Pelayanan                         1583242 non-null  category
#  13  Jenis_Poli                                1583242 non-null  category
#  14  Segmen_Peserta_Akses_Layanan              1583242 non-null  category
#  15  Kelas_Rawat_Peserta                       1583242 non-null  category
#  16  Status_Pulang                             1583242 non-null  category
#  17  Kode_Nama_Diagnosis_Masuk_ICD_10          1583242 non-null  category
#  18  Kode_Diagnosis_Masuk_ICD_10               1583242 non-null  object
#  19  Kode_ICD_10_Diagnosis_Masuk               1583242 non-null  object
#  20  Nama_Diagnosis_Masuk                      1583242 non-null  object
#  21  Kode_Nama_Diagnosis_Primer_ICD_10         1583242 non-null  category
#  22  Kode_Diagnosis_Primer_ICD_10              1583242 non-null  object
#  23  Kode_ICD_10_Diagnosis_Primer              1583242 non-null  object
#  24  Nama_Diagnosis_Primer                     1583242 non-null  object
#  25  Kode_INACBGs                              1583242 non-null  object
#  26  Deskripsi_Kode_INACBGs                    1583242 non-null  object
#  27  INACBGs_Kode_Casemix_Main_Groups          1583242 non-null  category
#  28  INACBGs_Tipe_Kelompok_Kasus               1583242 non-null  category
#  29  INACBGs_Spesifikasi_Kelompok_Kasus        1583242 non-null  int8
#  30  INACBGs_Tingkat_Keparahan_Kelompok_Kasus  1583242 non-null  category
#  31  Provinsi_Faskes_Perujuk                   1583241 non-null  category
#  32  Kabupaten_Kota_Faskes_Perujuk             1583241 non-null  category
#  33  Kepemilikan_Faskes_Perujuk                1583242 non-null  category
#  34  Jenis_Faskes_Perujuk                      1583242 non-null  category
#  35  Tipe_Faskes_Perujuk                       1583242 non-null  category
#  36  Jenis_Prosedur                            1583242 non-null  object
#  37  Tarif_Regional_INACBGs                    1583242 non-null  category
#  38  Group_Tarif_INACBGs                       1583242 non-null  int32
#  39  Kode_Special_Sub-Acute_Groups_SA          1583242 non-null  object
#  40  Tarif_Special_Sub-Acute_Groups_SA         1522041 non-null  float64
#  41  Kode_Special_Procedures_SP                1583242 non-null  object
#  42  Deskripsi_Special_Procedures_SP           1583242 non-null  object
#  43  Tarif_Special_Procedures_SP               1522041 non-null  float64
#  44  Kode_Special_Prosthesis_RR                1583242 non-null  object
#  45  Deskripsi_Special_Prosthesis_RR           1583242 non-null  object
#  46  Tarif_Special_Prosthesis_RR               1522041 non-null  float64
#  47  Kode_Special_Investigation_SI             1583242 non-null  object
#  48  Deskripsi_Special_Investigation_SI        1583242 non-null  object
#  49  Tarif_Special_Investigation_SI            1522041 non-null  float64
#  50  Kode_Special_Drugs_SD                     1583242 non-null  object
#  51  Deskripsi_Special_Drugs_SD                1583242 non-null  object
#  52  Tarif_Special_Drugs_SD                    1522041 non-null  float64
#  53  Biaya_Tagih_Faskes_Provider               1583242 non-null  int32
#  54  Biaya_Verifikasi                          1583242 non-null  int32
# dtypes: category(21), datetime64[ns](2), float32(1), float64(5), int32(5), int8(1), object(20)
# memory usage: 413.9+ MB

# %%
df_fkrtl_1.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_1.isna().sum().sum()
# Out:
# 306007

# %%
df_fkrtl_1.isna().sum()
# Out:
# Nomor_Peserta                                   0
# Nomor_Keluarga                                  0
# Bobot                                           0
# ID_Kunjungan_FKTP                               0
# ID_Kunjungan_FKRTL                              0
# Tanggal_Datang_Kunjungan                        0
# Tanggal_Pulang_Kunjungan                        0
# Provinsi                                        0
# Kabupaten_Kota                                  0
# Kepemilikan                                     0
# Jenis                                           0
# Tipe                                            0
# Tingkat_Pelayanan                               0
# Jenis_Poli                                      0
# Segmen_Peserta_Akses_Layanan                    0
# Kelas_Rawat_Peserta                             0
# Status_Pulang                                   0
# Kode_Nama_Diagnosis_Masuk_ICD_10                0
# Kode_Diagnosis_Masuk_ICD_10                     0
# Kode_ICD_10_Diagnosis_Masuk                     0
# Nama_Diagnosis_Masuk                            0
# Kode_Nama_Diagnosis_Primer_ICD_10               0
# Kode_Diagnosis_Primer_ICD_10                    0
# Kode_ICD_10_Diagnosis_Primer                    0
# Nama_Diagnosis_Primer                           0
# Kode_INACBGs                                    0
# Deskripsi_Kode_INACBGs                          0
# INACBGs_Kode_Casemix_Main_Groups                0
# INACBGs_Tipe_Kelompok_Kasus                     0
# INACBGs_Spesifikasi_Kelompok_Kasus              0
# INACBGs_Tingkat_Keparahan_Kelompok_Kasus        0
# Provinsi_Faskes_Perujuk                         1
# Kabupaten_Kota_Faskes_Perujuk                   1
# Kepemilikan_Faskes_Perujuk                      0
# Jenis_Faskes_Perujuk                            0
# Tipe_Faskes_Perujuk                             0
# Jenis_Prosedur                                  0
# Tarif_Regional_INACBGs                          0
# Group_Tarif_INACBGs                             0
# Kode_Special_Sub-Acute_Groups_SA                0
# Tarif_Special_Sub-Acute_Groups_SA           61201
# Kode_Special_Procedures_SP                      0
# Deskripsi_Special_Procedures_SP                 0
# Tarif_Special_Procedures_SP                 61201
# Kode_Special_Prosthesis_RR                      0
# Deskripsi_Special_Prosthesis_RR                 0
# Tarif_Special_Prosthesis_RR                 61201
# Kode_Special_Investigation_SI                   0
# Deskripsi_Special_Investigation_SI              0
# Tarif_Special_Investigation_SI              61201
# Kode_Special_Drugs_SD                           0
# Deskripsi_Special_Drugs_SD                      0
# Tarif_Special_Drugs_SD                      61201
# Biaya_Tagih_Faskes_Provider                     0
# Biaya_Verifikasi                                0
# dtype: int64

# %% [markdown]
# ### 1.3. Fasilitas Kesehatan Tingkat Pratama (FKTP) Non-Kapitasi

# %%
df_fktp_nk.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'PNK02', 'PNK03', 'PNK04', 'PNK05',
#        'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10', 'PNK11', 'PNK12', 'PNK13',
#        'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17', 'PNK18'],
#       dtype='object')

# %%
df_fktp_nk.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'PNK02' : 'ID_Kunjungan',
    'PNK03' : 'Tanggal_Kunjungan',
    'PNK04' : 'Tanggal_Tindakan',
    'PNK05' : 'Tanggal_Pulang',
    'PNK06' : 'Provinsi_Faskes',
    'PNK07' : 'Kode_Kab_Kota_Faskes',
    'PNK08' : 'Kepemilikan_Faskes',
    'PNK09' : 'Jenis_Faskes',
    'PNK10' : 'Tipe_Faskes',
    'PNK11' : 'Tingkat_Layanan',
    'PNK12' : 'Segmen_Peserta',
    'PNK13' : 'Kode_Nama_Diagnosis_ICD_10',
    'PNK13A': 'Kode_Diagnosis_ICD_10',
    'PNK14' : 'Kode_Diagnosis_3_5_Digit',
    'PNK15' : 'Nama_Diagnosis',
    'PNK16' : 'Nama_Tindakan',
    'PNK17' : 'Biaya_Tagih',
    'PNK18' : 'Biaya_Verifikasi',
    'PNK19' : 'Hasil_Pemeriksaan_GDP_1', # Gula Darah Puasa
    'PNK20' : 'Hasil_Pemeriksaan_GDP_2'
}, inplace=True)

# %%
df_fktp_nk.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga      Bobot      ID_Kunjungan  \
# 0       93858078        93216423   7.659537  183920215Y000376
# 1       93747649       346217457   1.800196   19500915Y000074
# 2      359887820        72989971   0.959155  250630919P000299
# 3       84126594        84126594   1.110887  326360919P001086
# 4       87558937        62126532  32.451832  252721019P001142
#
#   Tanggal_Kunjungan Tanggal_Tindakan Tanggal_Pulang     Provinsi_Faskes  \
# 0        2015-02-26       2015-02-26     2015-02-27    SULAWESI SELATAN
# 1        2015-09-21       2015-09-23     2015-09-23  KALIMANTAN SELATAN
# 2        2019-09-26       2019-09-29     2019-09-29               PAPUA
# 3        2019-09-09       2019-09-12     2019-09-12         JAWA TENGAH
# 4        2019-10-14       2019-10-17     2019-10-17         JAWA TENGAH
#
#   Kode_Kab_Kota_Faskes         Kepemilikan_Faskes    Jenis_Faskes  \
# 0                BARRU  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
# 1                TAPIN  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
# 2             JAYAPURA                     TNI AD  KLINIK PRATAMA
# 3              REMBANG  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
# 4              KEBUMEN  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
#
#          Tipe_Faskes Tingkat_Layanan Segmen_Peserta  \
# 0         RAWAT INAP            RITP       PBI APBN
# 1         RAWAT INAP            RITP       PBI APBN
# 2  KLINIK RAWAT INAP            RITP            PPU
# 3         RAWAT INAP            RITP       PBI APBN
# 4         RAWAT INAP            RITP       PBI APBN
#
#            Kode_Nama_Diagnosis_ICD_10 Kode_Diagnosis_ICD_10  \
# 0                                 NaN
# 1                                 NaN
# 2  A01 Typhoid and paratyphoid fevers                   A01
# 3  A01 Typhoid and paratyphoid fevers                   A01
# 4  A01 Typhoid and paratyphoid fevers                   A01
#
#   Kode_Diagnosis_3_5_Digit                  Nama_Diagnosis  \
# 0                     9999                            9999
# 1                     9999                            9999
# 2                     A010                   Typhoid fever
# 3                      A01  Typhoid and paratyphoid fevers
# 4                      A01  Typhoid and paratyphoid fevers
#
#                       Nama_Tindakan  Biaya_Tagih  Biaya_Verifikasi
# 0   Evakuasi medis / Ambulans Darat       120000            120000
# 1  Rawat Inap di R. Perawatan Biasa       240000            240000
# 2  Rawat Inap di R. Perawatan Biasa       600000            600000
# 3  Rawat Inap di R. Perawatan Biasa       480000            480000
# 4  Rawat Inap di R. Perawatan Biasa       600000            600000

# %%
df_fktp_nk.shape
# Out:
# (36493, 21)

# %%
df_fktp_nk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36493 entries, 0 to 36492
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nomor_Peserta               36493 non-null  int32
#  1   Nomor_Keluarga              36493 non-null  int32
#  2   Bobot                       36493 non-null  float32
#  3   ID_Kunjungan                36493 non-null  object
#  4   Tanggal_Kunjungan           36493 non-null  datetime64[ns]
#  5   Tanggal_Tindakan            36493 non-null  datetime64[ns]
#  6   Tanggal_Pulang              36493 non-null  datetime64[ns]
#  7   Provinsi_Faskes             36493 non-null  category
#  8   Kode_Kab_Kota_Faskes        36493 non-null  category
#  9   Kepemilikan_Faskes          36493 non-null  category
#  10  Jenis_Faskes                36493 non-null  category
#  11  Tipe_Faskes                 36493 non-null  category
#  12  Tingkat_Layanan             36493 non-null  category
#  13  Segmen_Peserta              36493 non-null  category
#  14  Kode_Nama_Diagnosis_ICD_10  36491 non-null  category
#  15  Kode_Diagnosis_ICD_10       36493 non-null  object
#  16  Kode_Diagnosis_3_5_Digit    36493 non-null  object
#  17  Nama_Diagnosis              36493 non-null  object
#  18  Nama_Tindakan               36493 non-null  category
#  19  Biaya_Tagih                 36493 non-null  int32
#  20  Biaya_Verifikasi            36493 non-null  int32
# dtypes: category(9), datetime64[ns](3), float32(1), int32(4), object(4)
# memory usage: 3.3+ MB

# %%
df_fktp_nk.duplicated().sum()
# Out:
# 487

# %%
df_fktp_nk.isna().sum().sum()
# Out:
# 2

# %%
df_fktp_nk.isna().sum()
# Out:
# Nomor_Peserta                 0
# Nomor_Keluarga                0
# Bobot                         0
# ID_Kunjungan                  0
# Tanggal_Kunjungan             0
# Tanggal_Tindakan              0
# Tanggal_Pulang                0
# Provinsi_Faskes               0
# Kode_Kab_Kota_Faskes          0
# Kepemilikan_Faskes            0
# Jenis_Faskes                  0
# Tipe_Faskes                   0
# Tingkat_Layanan               0
# Segmen_Peserta                0
# Kode_Nama_Diagnosis_ICD_10    2
# Kode_Diagnosis_ICD_10         0
# Kode_Diagnosis_3_5_Digit      0
# Nama_Diagnosis                0
# Nama_Tindakan                 0
# Biaya_Tagih                   0
# Biaya_Verifikasi              0
# dtype: int64

# %% [markdown]
# ### 1.4. FKRTL Diagnosis Sekunder

# %%
df_fkrtl_2.columns
# Out:
# Index(['FKL02', 'FKL24', 'FKL24A', 'FKL24B'], dtype='object')

# %%
df_fkrtl_2.rename(columns={
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL24' : 'Kode_Diagnosis_3_5_Digit',
    'FKL24A': 'Kode_Diagnosis_ICD_10',
    'FKL24B': 'Kode_Nama_Diagnosis_ICD_10'
}, inplace=True)

# %%
df_fkrtl_2.head()
# Out:
#   ID_Kunjungan_FKRTL Kode_Diagnosis_3_5_Digit Kode_Diagnosis_ICD_10  \
# 0   2603412140001163                     H814                   H81
# 1   1337801150000108                     M199                   M19
# 2   1571901150000730                    M4909                   M49
# 3   3039201150000052                     E790                   E79
# 4   3376701150000072                     N390                   N39
#
#                           Kode_Nama_Diagnosis_ICD_10
# 0               H81 Disorders of vestibular function
# 1                                M19 Other arthrosis
# 2  M49 Spondylopathies in diseases classified els...
# 3  E79 Disorders of purine and pyrimidine metabolism
# 4              N39 Other disorders of urinary system

# %%
df_fkrtl_2.shape
# Out:
# (1562211, 4)

# %%
df_fkrtl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1562211 entries, 0 to 1562210
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   ID_Kunjungan_FKRTL          1562211 non-null  object
#  1   Kode_Diagnosis_3_5_Digit    1562211 non-null  object
#  2   Kode_Diagnosis_ICD_10       1562211 non-null  object
#  3   Kode_Nama_Diagnosis_ICD_10  1562211 non-null  object
# dtypes: object(4)
# memory usage: 59.6+ MB

# %%
df_fkrtl_2.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_2.isna().sum().sum()
# Out:
# 0
