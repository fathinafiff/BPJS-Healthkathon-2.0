# %% [markdown]
# # 3. BPJS Kesehatan Tuberculosis

# %% [markdown]
# [Tuberculosis](https://www.who.int/health-topics/tuberculosis), or TB, is an infectious disease that can [affect](https://www.healthdirect.gov.au/tuberculosis) [any part of the body](https://www.nhsinform.scot/illnesses-and-conditions/infections-and-poisoning/tuberculosis-tb), including the glands, bones and nervous system, most often affects the lungs. TB is caused by a type of bacteria (*Mycobacterium tuberculosis*).

# %%
# Data manipulation
import numpy as np
import pandas as pd
import datetime as dt

# Data visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Matplotlib', mpl.__version__)
print('Seaborn', sns.__version__)
# Out:
# NumPy 1.23.5
# Pandas 1.5.3
# Matplotlib 3.7.1
# Seaborn 0.12.2

# %%
# Read the data files
df_19 = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB2019_kepesertaan.dta')
df_20 = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB2020_kepesertaan.dta')
df_21 = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB2021_kepesertaan.dta')
# df_fktp_k = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB20152021_fktpkapitasi.dta', convert_categoricals=False)
df_fkrtl_1 = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB20152021_fkrtl.dta')
df_fktp_nk = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB20152021_fktpnonkapitasi.dta')
df_fkrtl_2 = pd.read_stata('/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/Data Sampel Final 2022/Kontekstual TB/TB20152021_fkrtldxsekunder.dta')

# %% [markdown]
# ## 3.1. Hasil Data Sampel BPJS Kesehatan

# %% [markdown]
# ### 3.1.1. Kepesertaan BPJS Kesehatan

# %% [markdown]
# #### 3.1.1.1. Tahun 2019

# %%
df_19.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_19.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
df_19.drop([
    'Nomor_Keluarga', 'Hubungan_Keluarga', 'Status_Perkawinan', 'Segmen_Peserta',
    'Provinsi_Tempat_Tinggal_Peserta', 'Kabupaten_Kota_Tempat_Tinggal_Peserta', 'Bobot',
    # 'Tahun_Sampel'
    ], axis=1, inplace=True)

# %%
print('\nData in TB2019_kepesertaan.dta')
df_19.head()
# Out:
# Data in TB2019_kepesertaan.dta
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       21611150            1957-09-12     PEREMPUAN     KELAS I
# 1       94343049            1961-12-03     LAKI-LAKI     KELAS I
# 2       83393824            2002-10-05     LAKI-LAKI     KELAS I
# 3      328537885            1989-07-13     PEREMPUAN   KELAS III
# 4       67805935            1972-11-13     LAKI-LAKI     KELAS I
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta  Tahun_Sampel Status_Kepesertaan  \
# 0                    ACEH BESAR          2019              AKTIF
# 1                 ACEH TENGGARA          2019              AKTIF
# 2                 ACEH TENGGARA          2019              AKTIF
# 3                  ACEH TAMIANG          2019              AKTIF
# 4                  ACEH TAMIANG          2019              AKTIF
#
#    Tahun_Meninggal
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_19.shape
# Out:
# (94966, 11)

# %%
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nomor_Peserta                  94966 non-null  int32
#  1   Tanggal_Lahir_Peserta          94966 non-null  datetime64[ns]
#  2   Jenis_Kelamin                  94966 non-null  category
#  3   Kelas_Rawat                    94966 non-null  category
#  4   Kepemilikan_Faskes             94966 non-null  category
#  5   Jenis_Faskes                   94966 non-null  category
#  6   Provinsi_Faskes_Peserta        94966 non-null  category
#  7   Kabupaten_Kota_Faskes_Peserta  94966 non-null  category
#  8   Tahun_Sampel                   94966 non-null  int16
#  9   Status_Kepesertaan             94966 non-null  category
#  10  Tahun_Meninggal                4476 non-null   float64
# dtypes: category(7), datetime64[ns](1), float64(1), int16(1), int32(1)
# memory usage: 3.5 MB

# %%
df_19.duplicated().sum()
# Out:
# 0

# %%
df_19.isna().sum().sum()
# Out:
# 90490

# %%
df_19.isna().sum()
# Out:
# Nomor_Peserta                        0
# Tanggal_Lahir_Peserta                0
# Jenis_Kelamin                        0
# Kelas_Rawat                          0
# Kepemilikan_Faskes                   0
# Jenis_Faskes                         0
# Provinsi_Faskes_Peserta              0
# Kabupaten_Kota_Faskes_Peserta        0
# Tahun_Sampel                         0
# Status_Kepesertaan                   0
# Tahun_Meninggal                  90490
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 90.490.

# %%
df_19['Tahun_Meninggal'] = df_19['Tahun_Meninggal'].fillna(0).astype(int)
df_19['Tahun_Lahir'] = df_19['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_19['Tahun_Meninggal'] != 0,
                df_19['Tahun_Meninggal'] - df_19['Tahun_Lahir'],
                df_19['Tahun_Sampel'] - df_19['Tahun_Lahir'])
df_19.drop(['Tahun_Sampel'], axis=1, inplace=True)
df_19['Umur'] = umur.astype(int)

# %%
df_19.head()
# Out:
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       21611150            1957-09-12     PEREMPUAN     KELAS I
# 1       94343049            1961-12-03     LAKI-LAKI     KELAS I
# 2       83393824            2002-10-05     LAKI-LAKI     KELAS I
# 3      328537885            1989-07-13     PEREMPUAN   KELAS III
# 4       67805935            1972-11-13     LAKI-LAKI     KELAS I
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# 0                    ACEH BESAR              AKTIF                0
# 1                 ACEH TENGGARA              AKTIF                0
# 2                 ACEH TENGGARA              AKTIF                0
# 3                  ACEH TAMIANG              AKTIF                0
# 4                  ACEH TAMIANG              AKTIF                0
#
#    Tahun_Lahir  Umur
# 0         1957    62
# 1         1961    58
# 2         2002    17
# 3         1989    30
# 4         1972    47

# %%
df_19.describe(include='all')
# Out:
#         Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# count    9.496600e+04                 94966         94966       94966
# unique            NaN                 26362             2           3
# top               NaN   1960-07-01 00:00:00     LAKI-LAKI   KELAS III
# freq              NaN                   171         50610       55572
# first             NaN   1912-12-30 00:00:00           NaN         NaN
# last              NaN   2019-07-19 00:00:00           NaN         NaN
# mean     1.830281e+08                   NaN           NaN         NaN
# std      1.597607e+08                   NaN           NaN         NaN
# min      1.394000e+03                   NaN           NaN         NaN
# 25%      4.366800e+07                   NaN           NaN         NaN
# 50%      8.745586e+07                   NaN           NaN         NaN
# 75%      3.455679e+08                   NaN           NaN         NaN
# max      4.553809e+08                   NaN           NaN         NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        68772        68890                    9473
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# count                          94966              94966     94966.000000
# unique                           514                  3              NaN
# top                       KOTA MEDAN              AKTIF              NaN
# freq                             346              85515              NaN
# first                            NaN                NaN              NaN
# last                             NaN                NaN              NaN
# mean                             NaN                NaN        95.160837
# std                              NaN                NaN       427.873897
# min                              NaN                NaN         0.000000
# 25%                              NaN                NaN         0.000000
# 50%                              NaN                NaN         0.000000
# 75%                              NaN                NaN         0.000000
# max                              NaN                NaN      2019.000000
#
#          Tahun_Lahir          Umur
# count   94966.000000  94966.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean     1981.904819     37.095181
# std        21.737231     21.737231
# min      1912.000000      0.000000
# 25%      1964.000000     20.000000
# 50%      1982.000000     37.000000
# 75%      1999.000000     55.000000
# max      2019.000000    107.000000

# %% [markdown]
# #### 3.1.1.2. Tahun 2020

# %%
df_20.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_20.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
df_20.drop([
    'Nomor_Keluarga', 'Hubungan_Keluarga', 'Status_Perkawinan', 'Segmen_Peserta',
    'Provinsi_Tempat_Tinggal_Peserta', 'Kabupaten_Kota_Tempat_Tinggal_Peserta', 'Bobot',
    # 'Tahun_Sampel'
    ], axis=1, inplace=True)

# %%
print('\nData in TB2020_kepesertaan.dta')
df_20.head()
# Out:
# Data in TB2020_kepesertaan.dta
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       32853965            1958-11-27     LAKI-LAKI     KELAS I
# 1        8555967            1936-07-01     LAKI-LAKI     KELAS I
# 2        8797049            1950-07-21     LAKI-LAKI     KELAS I
# 3       83472658            2012-08-12     PEREMPUAN     KELAS I
# 4      425874326            2004-12-30     LAKI-LAKI    KELAS II
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH          2020          MENINGGAL
# 1                       BIREUEN          2020              AKTIF
# 2                  ACEH SELATAN          2020        TIDAK AKTIF
# 3                    ACEH BARAT          2020              AKTIF
# 4                  TOBA SAMOSIR          2020              AKTIF
#
#    Tahun_Meninggal
# 0           2020.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_20.shape
# Out:
# (94966, 11)

# %%
df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nomor_Peserta                  94966 non-null  int32
#  1   Tanggal_Lahir_Peserta          94966 non-null  datetime64[ns]
#  2   Jenis_Kelamin                  94966 non-null  category
#  3   Kelas_Rawat                    94966 non-null  category
#  4   Kepemilikan_Faskes             94966 non-null  category
#  5   Jenis_Faskes                   94966 non-null  category
#  6   Provinsi_Faskes_Peserta        94966 non-null  category
#  7   Kabupaten_Kota_Faskes_Peserta  94966 non-null  category
#  8   Tahun_Sampel                   94966 non-null  int16
#  9   Status_Kepesertaan             94966 non-null  category
#  10  Tahun_Meninggal                7147 non-null   float64
# dtypes: category(7), datetime64[ns](1), float64(1), int16(1), int32(1)
# memory usage: 3.5 MB

# %%
df_20.duplicated().sum()
# Out:
# 0

# %%
df_20.isna().sum().sum()
# Out:
# 87819

# %%
df_20.isna().sum()
# Out:
# Nomor_Peserta                        0
# Tanggal_Lahir_Peserta                0
# Jenis_Kelamin                        0
# Kelas_Rawat                          0
# Kepemilikan_Faskes                   0
# Jenis_Faskes                         0
# Provinsi_Faskes_Peserta              0
# Kabupaten_Kota_Faskes_Peserta        0
# Tahun_Sampel                         0
# Status_Kepesertaan                   0
# Tahun_Meninggal                  87819
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 87.819.

# %%
df_20['Tahun_Meninggal'] = df_20['Tahun_Meninggal'].fillna(0).astype(int)
df_20['Tahun_Lahir'] = df_20['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_20['Tahun_Meninggal'] != 0,
                df_20['Tahun_Meninggal'] - df_20['Tahun_Lahir'],
                df_20['Tahun_Sampel'] - df_20['Tahun_Lahir'])
df_20.drop(['Tahun_Sampel'], axis=1, inplace=True)
df_20['Umur'] = umur.astype(int)

# %%
df_20.head()
# Out:
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       32853965            1958-11-27     LAKI-LAKI     KELAS I
# 1        8555967            1936-07-01     LAKI-LAKI     KELAS I
# 2        8797049            1950-07-21     LAKI-LAKI     KELAS I
# 3       83472658            2012-08-12     PEREMPUAN     KELAS I
# 4      425874326            2004-12-30     LAKI-LAKI    KELAS II
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# 0                   ACEH TENGAH          MENINGGAL             2020
# 1                       BIREUEN              AKTIF                0
# 2                  ACEH SELATAN        TIDAK AKTIF                0
# 3                    ACEH BARAT              AKTIF                0
# 4                  TOBA SAMOSIR              AKTIF                0
#
#    Tahun_Lahir  Umur
# 0         1958    62
# 1         1936    84
# 2         1950    70
# 3         2012     8
# 4         2004    16

# %%
df_20.describe(include='all')
# Out:
#         Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# count    9.496600e+04                 94966         94966       94966
# unique            NaN                 26362             2           4
# top               NaN   1960-07-01 00:00:00     LAKI-LAKI   KELAS III
# freq              NaN                   171         50610       57629
# first             NaN   1912-12-30 00:00:00           NaN         NaN
# last              NaN   2019-07-19 00:00:00           NaN         NaN
# mean     1.830281e+08                   NaN           NaN         NaN
# std      1.597607e+08                   NaN           NaN         NaN
# min      1.394000e+03                   NaN           NaN         NaN
# 25%      4.366800e+07                   NaN           NaN         NaN
# 50%      8.745586e+07                   NaN           NaN         NaN
# 75%      3.455679e+08                   NaN           NaN         NaN
# max      4.553809e+08                   NaN           NaN         NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        68772        68890                    9473
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# count                          94966              94966     94966.000000
# unique                           514                  3              NaN
# top                       KOTA MEDAN              AKTIF              NaN
# freq                             346              75608              NaN
# first                            NaN                NaN              NaN
# last                             NaN                NaN              NaN
# mean                             NaN                NaN       151.974812
# std                              NaN                NaN       532.728912
# min                              NaN                NaN         0.000000
# 25%                              NaN                NaN         0.000000
# 50%                              NaN                NaN         0.000000
# 75%                              NaN                NaN         0.000000
# max                              NaN                NaN      2020.000000
#
#          Tahun_Lahir          Umur
# count   94966.000000  94966.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean     1981.904819     38.047796
# std        21.737231     21.708006
# min      1912.000000      0.000000
# 25%      1964.000000     21.000000
# 50%      1982.000000     38.000000
# 75%      1999.000000     56.000000
# max      2019.000000    107.000000

# %% [markdown]
# #### 3.1.1.3. Tahun 2021

# %%
df_21.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_21.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
df_21.drop([
    'Nomor_Keluarga', 'Hubungan_Keluarga', 'Status_Perkawinan', 'Segmen_Peserta',
    'Provinsi_Tempat_Tinggal_Peserta', 'Kabupaten_Kota_Tempat_Tinggal_Peserta', 'Bobot',
    # 'Tahun_Sampel'
    ], axis=1, inplace=True)

# %%
print('\nData in TB2021_kepesertaan.dta')
df_21.head()
# Out:
# Data in TB2021_kepesertaan.dta
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       32853965            1958-11-27     LAKI-LAKI     KELAS I
# 1        8555967            1936-07-01     LAKI-LAKI     KELAS I
# 2        8797049            1950-07-21     LAKI-LAKI     KELAS I
# 3       83472658            2012-08-12     PEREMPUAN     KELAS I
# 4      425874326            2004-12-30     LAKI-LAKI    KELAS II
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta  Tahun_Sampel Status_Kepesertaan  \
# 0                   ACEH TENGAH          2021          MENINGGAL
# 1                       BIREUEN          2021              AKTIF
# 2                  ACEH SELATAN          2021        TIDAK AKTIF
# 3                    ACEH BARAT          2021              AKTIF
# 4                  TOBA SAMOSIR          2021              AKTIF
#
#    Tahun_Meninggal
# 0           2020.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_21.shape
# Out:
# (94966, 11)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94966 entries, 0 to 94965
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nomor_Peserta                  94966 non-null  int32
#  1   Tanggal_Lahir_Peserta          94966 non-null  datetime64[ns]
#  2   Jenis_Kelamin                  94966 non-null  category
#  3   Kelas_Rawat                    94966 non-null  category
#  4   Kepemilikan_Faskes             94966 non-null  category
#  5   Jenis_Faskes                   94966 non-null  category
#  6   Provinsi_Faskes_Peserta        94966 non-null  category
#  7   Kabupaten_Kota_Faskes_Peserta  94966 non-null  category
#  8   Tahun_Sampel                   94966 non-null  int16
#  9   Status_Kepesertaan             94966 non-null  category
#  10  Tahun_Meninggal                8654 non-null   float64
# dtypes: category(7), datetime64[ns](1), float64(1), int16(1), int32(1)
# memory usage: 3.5 MB

# %%
df_21.duplicated().sum()
# Out:
# 0

# %%
df_21.isna().sum().sum()
# Out:
# 86312

# %%
df_21.isna().sum()
# Out:
# Nomor_Peserta                        0
# Tanggal_Lahir_Peserta                0
# Jenis_Kelamin                        0
# Kelas_Rawat                          0
# Kepemilikan_Faskes                   0
# Jenis_Faskes                         0
# Provinsi_Faskes_Peserta              0
# Kabupaten_Kota_Faskes_Peserta        0
# Tahun_Sampel                         0
# Status_Kepesertaan                   0
# Tahun_Meninggal                  86312
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 86.312.

# %%
df_21['Tahun_Meninggal'] = df_21['Tahun_Meninggal'].fillna(0).astype(int)
df_21['Tahun_Lahir'] = df_21['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_21['Tahun_Meninggal'] != 0,
                df_21['Tahun_Meninggal'] - df_21['Tahun_Lahir'],
                df_21['Tahun_Sampel'] - df_21['Tahun_Lahir'])
df_21.drop(['Tahun_Sampel'], axis=1, inplace=True)
df_21['Umur'] = umur.astype(int)

# %%
df_21.head()
# Out:
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       32853965            1958-11-27     LAKI-LAKI     KELAS I
# 1        8555967            1936-07-01     LAKI-LAKI     KELAS I
# 2        8797049            1950-07-21     LAKI-LAKI     KELAS I
# 3       83472658            2012-08-12     PEREMPUAN     KELAS I
# 4      425874326            2004-12-30     LAKI-LAKI    KELAS II
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# 0                   ACEH TENGAH          MENINGGAL             2020
# 1                       BIREUEN              AKTIF                0
# 2                  ACEH SELATAN        TIDAK AKTIF                0
# 3                    ACEH BARAT              AKTIF                0
# 4                  TOBA SAMOSIR              AKTIF                0
#
#    Tahun_Lahir  Umur
# 0         1958    62
# 1         1936    85
# 2         1950    71
# 3         2012     9
# 4         2004    17

# %%
df_21.describe(include='all')
# Out:
#         Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# count    9.496600e+04                 94966         94966       94966
# unique            NaN                 26362             2           4
# top               NaN   1960-07-01 00:00:00     LAKI-LAKI   KELAS III
# freq              NaN                   171         50610       57594
# first             NaN   1912-12-30 00:00:00           NaN         NaN
# last              NaN   2019-07-19 00:00:00           NaN         NaN
# mean     1.830281e+08                   NaN           NaN         NaN
# std      1.597607e+08                   NaN           NaN         NaN
# min      1.394000e+03                   NaN           NaN         NaN
# 25%      4.366800e+07                   NaN           NaN         NaN
# 50%      8.745586e+07                   NaN           NaN         NaN
# 75%      3.455679e+08                   NaN           NaN         NaN
# max      4.553809e+08                   NaN           NaN         NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                       94966        94966                   94966
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        69160        69282                    9514
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# count                          94966              94966     94966.000000
# unique                           514                  4              NaN
# top                       KOTA MEDAN              AKTIF              NaN
# freq                             409              69686              NaN
# first                            NaN                NaN              NaN
# last                             NaN                NaN              NaN
# mean                             NaN                NaN       184.045932
# std                              NaN                NaN       581.240260
# min                              NaN                NaN         0.000000
# 25%                              NaN                NaN         0.000000
# 50%                              NaN                NaN         0.000000
# 75%                              NaN                NaN         0.000000
# max                              NaN                NaN      2021.000000
#
#          Tahun_Lahir          Umur
# count   94966.000000  94966.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# first            NaN           NaN
# last             NaN           NaN
# mean     1981.904819     38.972738
# std        21.737231     21.663097
# min      1912.000000      0.000000
# 25%      1964.000000     22.000000
# 50%      1982.000000     39.000000
# 75%      1999.000000     57.000000
# max      2019.000000    107.000000

# %% [markdown]
# #### 3.1.1.4. Menggabungkan Data Tahun 2019–2021

# %%
df_19.shape
# Out:
# (94966, 12)

# %%
df_20.shape
# Out:
# (94966, 12)

# %%
df_21.shape
# Out:
# (94966, 12)

# %%
# Append DataFrames
df_19_21 = df_21.append([df_20, df_19])

# Remove duplicates based on 'Nomor_Peserta', keeping the first occurrence
df_19_21 = df_19_21.drop_duplicates(subset='Nomor_Peserta', keep='first')

# %%
df_19_21.head()
# Out:
#    Nomor_Peserta Tanggal_Lahir_Peserta Jenis_Kelamin Kelas_Rawat  \
# 0       32853965            1958-11-27     LAKI-LAKI     KELAS I
# 1        8555967            1936-07-01     LAKI-LAKI     KELAS I
# 2        8797049            1950-07-21     LAKI-LAKI     KELAS I
# 3       83472658            2012-08-12     PEREMPUAN     KELAS I
# 4      425874326            2004-12-30     LAKI-LAKI    KELAS II
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 1                      POLRI  KLINIK PRATAMA                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS          SUMATERA UTARA
#
#   Kabupaten_Kota_Faskes_Peserta Status_Kepesertaan  Tahun_Meninggal  \
# 0                   ACEH TENGAH          MENINGGAL             2020
# 1                       BIREUEN              AKTIF                0
# 2                  ACEH SELATAN        TIDAK AKTIF                0
# 3                    ACEH BARAT              AKTIF                0
# 4                  TOBA SAMOSIR              AKTIF                0
#
#    Tahun_Lahir  Umur
# 0         1958    62
# 1         1936    85
# 2         1950    71
# 3         2012     9
# 4         2004    17

# %%
df_19_21.shape
# Out:
# (94966, 12)

# %%
df_19_21.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3.1.2. Fasilitas Kesehatan Rujukan Tingkat Lanjutan (FKRTL) Diagnosis Primer

# %%
df_fkrtl_1.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48'],
#       dtype='object')

# %%
df_fkrtl_1.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'FKP02' : 'ID_Kunjungan_FKTP',
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL03' : 'Tanggal_Datang_Kunjungan',
    'FKL04' : 'Tanggal_Pulang_Kunjungan',
    'FKL05' : 'Provinsi',
    'FKL06' : 'Kabupaten_Kota',
    'FKL07' : 'Kepemilikan',
    'FKL08' : 'Jenis',
    'FKL09' : 'Tipe',
    'FKL10' : 'Tingkat_Pelayanan',
    'FKL11' : 'Jenis_Poli',
    'FKL12' : 'Segmen_Peserta_Akses_Layanan',
    'FKL13' : 'Kelas_Rawat_Peserta',
    'FKL14' : 'Status_Pulang',
    'FKL15' : 'Kode_Nama_Diagnosis_Masuk_ICD_10',
    'FKL15A': 'Kode_Diagnosis_Masuk_ICD_10',
    'FKL16' : 'Kode_ICD_10_Diagnosis_Masuk',
    'FKL16A': 'Nama_Diagnosis_Masuk',
    'FKL17' : 'Kode_Nama_Diagnosis_Primer_ICD_10',
    'FKL17A': 'Kode_Diagnosis_Primer_ICD_10',
    'FKL18' : 'Kode_ICD_10_Diagnosis_Primer',
    'FKL18A': 'Nama_Diagnosis_Primer',
    'FKL19' : 'Kode_INACBGs',
    'FKL19A': 'Deskripsi_Kode_INACBGs',
    'FKL20' : 'INACBGs_Kode_Casemix_Main_Groups',
    'FKL21' : 'INACBGs_Tipe_Kelompok_Kasus',
    'FKL22' : 'INACBGs_Spesifikasi_Kelompok_Kasus',
    'FKL23' : 'INACBGs_Tingkat_Keparahan_Kelompok_Kasus',
    'FKL25' : 'Provinsi_Faskes_Perujuk',
    'FKL26' : 'Kabupaten_Kota_Faskes_Perujuk',
    'FKL27' : 'Kepemilikan_Faskes_Perujuk',
    'FKL28' : 'Jenis_Faskes_Perujuk',
    'FKL29' : 'Tipe_Faskes_Perujuk',
    'FKL30' : 'Jenis_Prosedur',
    'FKL31' : 'Tarif_Regional_INACBGs',
    'FKL32' : 'Group_Tarif_INACBGs',
    'FKL33' : 'Kode_Special_Sub-Acute_Groups_SA',
    'FKL34' : 'Tarif_Special_Sub-Acute_Groups_SA',
    'FKL35' : 'Kode_Special_Procedures_SP',
    'FKL36' : 'Deskripsi_Special_Procedures_SP',
    'FKL37' : 'Tarif_Special_Procedures_SP',
    'FKL38' : 'Kode_Special_Prosthesis_RR',
    'FKL39' : 'Deskripsi_Special_Prosthesis_RR',
    'FKL40' : 'Tarif_Special_Prosthesis_RR',
    'FKL41' : 'Kode_Special_Investigation_SI',
    'FKL42' : 'Deskripsi_Special_Investigation_SI',
    'FKL43' : 'Tarif_Special_Investigation_SI',
    'FKL44' : 'Kode_Special_Drugs_SD',
    'FKL45' : 'Deskripsi_Special_Drugs_SD',
    'FKL46' : 'Tarif_Special_Drugs_SD',
    'FKL47' : 'Biaya_Tagih_Faskes_Provider',
    'FKL48' : 'Biaya_Verifikasi'
}, inplace=True)

# %%
df_fkrtl_1.drop([
    'Nomor_Keluarga', 'Bobot', 'Tipe', 'Tingkat_Pelayanan', 'Jenis_Poli', 'Segmen_Peserta_Akses_Layanan',
    # 'Tanggal_Datang_Kunjungan', 'Tanggal_Pulang_Kunjungan',
    'Kode_Nama_Diagnosis_Masuk_ICD_10', 'Kode_Diagnosis_Masuk_ICD_10', 'Kode_ICD_10_Diagnosis_Masuk', 'Nama_Diagnosis_Masuk',
    'Kode_Nama_Diagnosis_Primer_ICD_10', 'Kode_Diagnosis_Primer_ICD_10', 'Kode_ICD_10_Diagnosis_Primer', 'Nama_Diagnosis_Primer',
    'Kode_INACBGs', 'Deskripsi_Kode_INACBGs', 'INACBGs_Kode_Casemix_Main_Groups',
    'INACBGs_Tipe_Kelompok_Kasus', 'INACBGs_Spesifikasi_Kelompok_Kasus', 'INACBGs_Tingkat_Keparahan_Kelompok_Kasus',
    'Provinsi_Faskes_Perujuk', 'Kabupaten_Kota_Faskes_Perujuk', 'Kepemilikan_Faskes_Perujuk', 'Jenis_Faskes_Perujuk', 'Tipe_Faskes_Perujuk', 'Jenis_Prosedur',
    'Tarif_Regional_INACBGs', 'Group_Tarif_INACBGs',
    'Kode_Special_Sub-Acute_Groups_SA', 'Tarif_Special_Sub-Acute_Groups_SA',
    'Kode_Special_Procedures_SP', 'Deskripsi_Special_Procedures_SP', 'Tarif_Special_Procedures_SP',
    'Kode_Special_Prosthesis_RR', 'Deskripsi_Special_Prosthesis_RR', 'Tarif_Special_Prosthesis_RR',
    'Kode_Special_Investigation_SI', 'Deskripsi_Special_Investigation_SI', 'Tarif_Special_Investigation_SI',
    'Kode_Special_Drugs_SD', 'Deskripsi_Special_Drugs_SD', 'Tarif_Special_Drugs_SD',
    'Biaya_Tagih_Faskes_Provider', 'Biaya_Verifikasi'
    ], axis=1, inplace=True)

# %%
df_fkrtl_1.head()
# Out:
#    Nomor_Peserta ID_Kunjungan_FKTP ID_Kunjungan_FKRTL  \
# 0       96934726                     1000801150000582
# 1       11315168                     1000801150001076
# 2       48014275                     1000801160000002
# 3       78552717                     1000801160000219
# 4       48014275                     1000801160000321
#
#   Tanggal_Datang_Kunjungan Tanggal_Pulang_Kunjungan Provinsi Kabupaten_Kota  \
# 0               2015-01-21               2015-01-21    PAPUA       JAYAPURA
# 1               2015-01-13               2015-01-13    PAPUA       JAYAPURA
# 2               2016-01-02               2016-01-06    PAPUA       JAYAPURA
# 3               2016-01-08               2016-01-08    PAPUA       JAYAPURA
# 4               2016-01-11               2016-01-11    PAPUA       JAYAPURA
#
#            Kepemilikan        Jenis Kelas_Rawat_Peserta Status_Pulang
# 0  Pemerintah kab/kota  Rumah sakit             Kelas 3         Sehat
# 1  Pemerintah kab/kota  Rumah sakit             Kelas 3         Sehat
# 2  Pemerintah kab/kota  Rumah sakit             Kelas 3         Sehat
# 3  Pemerintah kab/kota  Rumah sakit             Kelas 3         Sehat
# 4  Pemerintah kab/kota  Rumah sakit             Kelas 3         Sehat

# %%
df_fkrtl_1.shape
# Out:
# (1583242, 11)

# %%
df_fkrtl_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1583242 entries, 0 to 1583241
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Nomor_Peserta             1583242 non-null  int32
#  1   ID_Kunjungan_FKTP         1583242 non-null  object
#  2   ID_Kunjungan_FKRTL        1583242 non-null  object
#  3   Tanggal_Datang_Kunjungan  1583242 non-null  datetime64[ns]
#  4   Tanggal_Pulang_Kunjungan  1583242 non-null  datetime64[ns]
#  5   Provinsi                  1583242 non-null  category
#  6   Kabupaten_Kota            1583242 non-null  category
#  7   Kepemilikan               1583242 non-null  category
#  8   Jenis                     1583242 non-null  category
#  9   Kelas_Rawat_Peserta       1583242 non-null  category
#  10  Status_Pulang             1583242 non-null  category
# dtypes: category(6), datetime64[ns](2), int32(1), object(2)
# memory usage: 77.0+ MB

# %%
df_fkrtl_1.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_1.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 3.1.3. Fasilitas Kesehatan Tingkat Pratama (FKTP) Non-Kapitasi

# %%
df_fktp_nk.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'PNK02', 'PNK03', 'PNK04', 'PNK05',
#        'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10', 'PNK11', 'PNK12', 'PNK13',
#        'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17', 'PNK18'],
#       dtype='object')

# %%
df_fktp_nk.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'PNK02' : 'ID_Kunjungan',
    'PNK03' : 'Tanggal_Kunjungan',
    'PNK04' : 'Tanggal_Tindakan',
    'PNK05' : 'Tanggal_Pulang',
    'PNK06' : 'Provinsi_Faskes',
    'PNK07' : 'Kode_Kab_Kota_Faskes',
    'PNK08' : 'Kepemilikan_Faskes',
    'PNK09' : 'Jenis_Faskes',
    'PNK10' : 'Tipe_Faskes',
    'PNK11' : 'Tingkat_Layanan',
    'PNK12' : 'Segmen_Peserta',
    'PNK13' : 'Kode_Nama_Diagnosis_ICD_10',
    'PNK13A': 'Kode_Diagnosis_ICD_10',
    'PNK14' : 'Kode_Diagnosis_3_5_Digit',
    'PNK15' : 'Nama_Diagnosis',
    'PNK16' : 'Nama_Tindakan',
    'PNK17' : 'Biaya_Tagih',
    'PNK18' : 'Biaya_Verifikasi',
    'PNK19' : 'Hasil_Pemeriksaan_GDP_1', # Gula Darah Puasa
    'PNK20' : 'Hasil_Pemeriksaan_GDP_2'
}, inplace=True)

# %%
df_fktp_nk.drop([
    'Nomor_Keluarga', 'Bobot',
    'Tipe_Faskes', 'Tingkat_Layanan', 'Segmen_Peserta',
    'Kode_Nama_Diagnosis_ICD_10', 'Kode_Diagnosis_ICD_10',
    'Kode_Diagnosis_3_5_Digit', 'Nama_Diagnosis',
    'Biaya_Tagih', 'Biaya_Verifikasi',
    # 'Hasil_Pemeriksaan_GDP_1', 'Hasil_Pemeriksaan_GDP_2'
    ], axis=1, inplace=True)

# %%
df_fktp_nk.head()
# Out:
#    Nomor_Peserta      ID_Kunjungan Tanggal_Kunjungan Tanggal_Tindakan  \
# 0       93858078  183920215Y000376        2015-02-26       2015-02-26
# 1       93747649   19500915Y000074        2015-09-21       2015-09-23
# 2      359887820  250630919P000299        2019-09-26       2019-09-29
# 3       84126594  326360919P001086        2019-09-09       2019-09-12
# 4       87558937  252721019P001142        2019-10-14       2019-10-17
#
#   Tanggal_Pulang     Provinsi_Faskes Kode_Kab_Kota_Faskes  \
# 0     2015-02-27    SULAWESI SELATAN                BARRU
# 1     2015-09-23  KALIMANTAN SELATAN                TAPIN
# 2     2019-09-29               PAPUA             JAYAPURA
# 3     2019-09-12         JAWA TENGAH              REMBANG
# 4     2019-10-17         JAWA TENGAH              KEBUMEN
#
#           Kepemilikan_Faskes    Jenis_Faskes                     Nama_Tindakan
# 0  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS   Evakuasi medis / Ambulans Darat
# 1  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS  Rawat Inap di R. Perawatan Biasa
# 2                     TNI AD  KLINIK PRATAMA  Rawat Inap di R. Perawatan Biasa
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS  Rawat Inap di R. Perawatan Biasa
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS  Rawat Inap di R. Perawatan Biasa

# %%
df_fktp_nk.shape
# Out:
# (36493, 10)

# %%
df_fktp_nk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36493 entries, 0 to 36492
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nomor_Peserta         36493 non-null  int32
#  1   ID_Kunjungan          36493 non-null  object
#  2   Tanggal_Kunjungan     36493 non-null  datetime64[ns]
#  3   Tanggal_Tindakan      36493 non-null  datetime64[ns]
#  4   Tanggal_Pulang        36493 non-null  datetime64[ns]
#  5   Provinsi_Faskes       36493 non-null  category
#  6   Kode_Kab_Kota_Faskes  36493 non-null  category
#  7   Kepemilikan_Faskes    36493 non-null  category
#  8   Jenis_Faskes          36493 non-null  category
#  9   Nama_Tindakan         36493 non-null  category
# dtypes: category(5), datetime64[ns](3), int32(1), object(1)
# memory usage: 1.8+ MB

# %%
df_fktp_nk.duplicated().sum()
# Out:
# 489

# %%
df_fktp_nk.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 3.1.4. FKRTL Diagnosis Sekunder

# %%
df_fkrtl_2.columns
# Out:
# Index(['FKL02', 'FKL24', 'FKL24A', 'FKL24B'], dtype='object')

# %%
df_fkrtl_2.rename(columns={
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL24' : 'Kode_Diagnosis_3_5_Digit',
    'FKL24A': 'Kode_Diagnosis_ICD_10',
    'FKL24B': 'Kode_Nama_Diagnosis_ICD_10'
}, inplace=True)

# %%
df_fkrtl_2.head()
# Out:
#   ID_Kunjungan_FKRTL Kode_Diagnosis_3_5_Digit Kode_Diagnosis_ICD_10  \
# 0   2603412140001163                     H814                   H81
# 1   1337801150000108                     M199                   M19
# 2   1571901150000730                    M4909                   M49
# 3   3039201150000052                     E790                   E79
# 4   3376701150000072                     N390                   N39
#
#                           Kode_Nama_Diagnosis_ICD_10
# 0               H81 Disorders of vestibular function
# 1                                M19 Other arthrosis
# 2  M49 Spondylopathies in diseases classified els...
# 3  E79 Disorders of purine and pyrimidine metabolism
# 4              N39 Other disorders of urinary system

# %%
df_fkrtl_2.shape
# Out:
# (1562211, 4)

# %%
df_fkrtl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1562211 entries, 0 to 1562210
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   ID_Kunjungan_FKRTL          1562211 non-null  object
#  1   Kode_Diagnosis_3_5_Digit    1562211 non-null  object
#  2   Kode_Diagnosis_ICD_10       1562211 non-null  object
#  3   Kode_Nama_Diagnosis_ICD_10  1562211 non-null  object
# dtypes: object(4)
# memory usage: 59.6+ MB

# %%
df_fkrtl_2.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_2.isna().sum().sum()
# Out:
# 0

# %%
df_fkrtl_2.drop(['Kode_Diagnosis_ICD_10', 'Kode_Nama_Diagnosis_ICD_10'], axis=1, inplace=True)

# %%
df_fkrtl_2.head()
# Out:
#   ID_Kunjungan_FKRTL Kode_Diagnosis_3_5_Digit
# 0   2603412140001163                     H814
# 1   1337801150000108                     M199
# 2   1571901150000730                    M4909
# 3   3039201150000052                     E790
# 4   3376701150000072                     N390

# %% [markdown]
# ## 3.2. Menggabungkan Data

# %%
df_1 = df_19_21.copy()
df_2 = df_fkrtl_1.copy()
df_3 = df_fktp_nk.copy()

# %%
# Merge df_1 with df_2
fkrtl_merged_df = df_1.merge(df_2, on='Nomor_Peserta', how='inner')

# Merge df_1 with df_3
# Select necessary columns from df_3
df_3 = df_3.loc[:, ~df_3.columns.isin([
    'Provinsi_Faskes', 'Kode_Kab_Kota_Faskes',
    'Kepemilikan_Faskes', 'Jenis_Faskes'
    ])]
fktp_merged_df = df_1.merge(df_3, on='Nomor_Peserta', how='inner')

# Merge fktp_merged_df with df_2
# Select necessary columns from df_2
df_2 = df_2.loc[:, ~df_2.columns.isin([
    'Nomor_Peserta', 'Lama_Kunjungan'
    ])]
fktp_fkrtl_df = fktp_merged_df.merge(df_2, left_on='ID_Kunjungan', right_on='ID_Kunjungan_FKTP', how='inner')

# %% [markdown]
# ## 3.3. Mengekspor Data

# %%
# Define the directory
directory = '/content/drive/MyDrive/BPJS-Healthkathon-2.0-main/Files/'

# %%
# Export fktp_merged_df to a CSV file
fktp_merged_df.to_csv(directory + 'data_kepesertaan_pelayanan_fktp_TB.csv', index=False)

# Export fkrtl_merged_df to a CSV file
fkrtl_merged_df.to_csv(directory + 'data_kepesertaan_pelayanan_fkrt_TB.csv', index=False)

# Export fktp_fkrtl_df to a CSV file
fktp_fkrtl_df.to_csv(directory + 'data_pelayanan_fktp_fkrtl_TB.csv', index=False)
