# %% [markdown]
# # Diabetes Mellitus

# %% [markdown]
# [Diabetes](https://www.who.int/health-topics/diabetes) [mellitus](https://www.healthdirect.gov.au/diabetes), or DM, more commonly known simply as diabetes, is a group of diseases that can cause high levels of glucose in the blood. There are two main [types of diabetes](https://www.nhsinform.scot/illnesses-and-conditions/diabetes/diabetes):
# - Type 1 – where the pancreas doesn't produce any insulin
# - Type 2 – where the pancreas doesn't produce enough insulin or the body’s cells don't react to insulin

# %%
# Data manipulation
import numpy as np
import pandas as pd
import datetime as dt

# Data visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Matplotlib', mpl.__version__)
print('Seaborn', sns.__version__)
# Out:
# NumPy 1.23.5
# Pandas 1.5.3
# Matplotlib 3.7.1
# Seaborn 0.12.2

# %%
# Read the data files
df_19 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2019_kepesertaan.dta')
df_20 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2020_kepesertaan.dta')
df_21 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2021_kepesertaan.dta')
df_fktp_k = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2021_fktpkapitasi.dta', convert_categoricals=False)
df_fkrtl_1 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2021_fkrtl.dta')
df_fktp_n = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2021_fktpnonkapitasi.dta')
df_fkrtl_2 = pd.read_stata('/content/drive/MyDrive/Extra Space/Healthkathon/Data Sampel Final 2022/Kontekstual DM/DM2021_fkrtldxsekunder.dta')

# %% [markdown]
# ## 1. Hasil Data Sampel BPJS Kesehatan

# %% [markdown]
# ### 1.1. Kepesertaan BPJS Kesehatan

# %% [markdown]
# #### 1.1.1. Tahun 2019

# %%
df_19.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_19.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in DM2019_kepesertaan.dta')
df_19.head()
# Out:
# Data in DM2019_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       45243428        45243428            1959-10-11           PESERTA
# 1      356470819       356470819            1965-12-31           PESERTA
# 2       72280409       375793382            1964-08-03             ISTRI
# 3       88501975        88501975            1959-10-02           PESERTA
# 4       94870095       310527655            1947-01-01             SUAMI
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     PEREMPUAN             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I            PPU
# 2     PEREMPUAN             CERAI     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN             KAWIN     KELAS I            PPU
# 4     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                  SUMATERA UTARA                             BATU BARA
# 3                  SUMATERA UTARA                                ASAHAN
# 4                  SUMATERA BARAT                       PESISIR SELATAN
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA UTARA
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA UTARA
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA BARAT
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.468968          2020              AKTIF
# 1               KOTA BANDA ACEH   9.863322          2020              AKTIF
# 2                     BATU BARA   8.487743          2020              AKTIF
# 3                        ASAHAN  10.726228          2020          MENINGGAL
# 4               PESISIR SELATAN  10.539836          2020              AKTIF
#
#    Tahun_Meninggal
# 0              NaN
# 1              NaN
# 2              NaN
# 3           2019.0
# 4              NaN

# %%
df_19.shape
# Out:
# (143496, 18)

# %%
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Nomor_Peserta                          143496 non-null  int32
#  1   Nomor_Keluarga                         143496 non-null  int32
#  2   Tanggal_Lahir_Peserta                  143496 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      143496 non-null  category
#  4   Jenis_Kelamin                          143496 non-null  category
#  5   Status_Perkawinan                      143496 non-null  category
#  6   Kelas_Rawat                            143496 non-null  category
#  7   Segmen_Peserta                         143496 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        143496 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  143496 non-null  category
#  10  Kepemilikan_Faskes                     143496 non-null  category
#  11  Jenis_Faskes                           143496 non-null  category
#  12  Provinsi_Faskes_Peserta                143496 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          143496 non-null  category
#  14  Bobot                                  143496 non-null  float32
#  15  Tahun_Sampel                           143496 non-null  int16
#  16  Status_Kepesertaan                     143496 non-null  category
#  17  Tahun_Meninggal                        10268 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 7.2 MB

# %%
df_19.duplicated().sum()
# Out:
# 0

# %%
df_19.isna().sum().sum()
# Out:
# 133228

# %%
df_19.isna().sum()
# Out:
# Nomor_Peserta                                 0
# Nomor_Keluarga                                0
# Tanggal_Lahir_Peserta                         0
# Hubungan_Keluarga                             0
# Jenis_Kelamin                                 0
# Status_Perkawinan                             0
# Kelas_Rawat                                   0
# Segmen_Peserta                                0
# Provinsi_Tempat_Tinggal_Peserta               0
# Kabupaten_Kota_Tempat_Tinggal_Peserta         0
# Kepemilikan_Faskes                            0
# Jenis_Faskes                                  0
# Provinsi_Faskes_Peserta                       0
# Kabupaten_Kota_Faskes_Peserta                 0
# Bobot                                         0
# Tahun_Sampel                                  0
# Status_Kepesertaan                            0
# Tahun_Meninggal                          133228
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 133.228.

# %%
df_19['Tahun_Meninggal'] = df_19['Tahun_Meninggal'].fillna(0).astype(int)
df_19['Tahun_Lahir'] = df_19['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_19['Tahun_Meninggal'] != 0,
                df_19['Tahun_Meninggal'] - df_19['Tahun_Lahir'],
                df_19['Tahun_Sampel'] - df_19['Tahun_Lahir'])
df_19['Umur'] = umur.astype(int)

# %%
df_19.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       45243428        45243428            1959-10-11           PESERTA
# 1      356470819       356470819            1965-12-31           PESERTA
# 2       72280409       375793382            1964-08-03             ISTRI
# 3       88501975        88501975            1959-10-02           PESERTA
# 4       94870095       310527655            1947-01-01             SUAMI
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     PEREMPUAN             KAWIN     KELAS I            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I            PPU
# 2     PEREMPUAN             CERAI     KELAS I  BUKAN PEKERJA
# 3     PEREMPUAN             KAWIN     KELAS I            PPU
# 4     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                  SUMATERA UTARA                             BATU BARA
# 3                  SUMATERA UTARA                                ASAHAN
# 4                  SUMATERA BARAT                       PESISIR SELATAN
#
#           Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 1  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA UTARA
# 3  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA UTARA
# 4  PEMERINTAH KABUPATEN/KOTA    PUSKESMAS          SUMATERA BARAT
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.468968          2020              AKTIF
# 1               KOTA BANDA ACEH   9.863322          2020              AKTIF
# 2                     BATU BARA   8.487743          2020              AKTIF
# 3                        ASAHAN  10.726228          2020          MENINGGAL
# 4               PESISIR SELATAN  10.539836          2020              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0                0         1959    61
# 1                0         1965    55
# 2                0         1964    56
# 3             2019         1959    60
# 4                0         1947    73

# %%
df_19.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    1.434960e+05    1.434960e+05                143496            143496
# unique            NaN             NaN                 18552                 5
# top               NaN             NaN   1960-12-31 00:00:00           PESERTA
# freq              NaN             NaN                   441             85100
# first             NaN             NaN   1899-12-30 00:00:00               NaN
# last              NaN             NaN   2018-06-12 00:00:00               NaN
# mean     1.015970e+08    1.216283e+08                   NaN               NaN
# std      1.209830e+08    1.363905e+08                   NaN               NaN
# min      9.680000e+02    5.170000e+02                   NaN               NaN
# 25%      3.011237e+07    3.239370e+07                   NaN               NaN
# 50%      5.977754e+07    6.482657e+07                   NaN               NaN
# 75%      8.989074e+07    9.736831e+07                   NaN               NaN
# max      4.553888e+08    4.553888e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count         143496            143496      143496         143496
# unique             2                 3           3              5
# top        PEREMPUAN             KAWIN     KELAS I           PBPU
# freq           85829            120142       55547          42738
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                           143496                                143496
# unique                              35                                   483
# top                         JAWA TIMUR                         KOTA SURABAYA
# freq                             23422                                  3899
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                      143496       143496                  143496
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        84405        86105                   23514
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta          Bobot  Tahun_Sampel  \
# count                         143496  143496.000000      143496.0
# unique                           488            NaN           NaN
# top                    KOTA SURABAYA            NaN           NaN
# freq                            4098            NaN           NaN
# first                            NaN            NaN           NaN
# last                             NaN            NaN           NaN
# mean                             NaN      10.004865        2020.0
# std                              NaN       3.666396           0.0
# min                              NaN       0.351047        2020.0
# 25%                              NaN       8.047610        2020.0
# 50%                              NaN      11.459408        2020.0
# 75%                              NaN      12.782674        2020.0
# max                              NaN      38.295937        2020.0
#
#        Status_Kepesertaan  Tahun_Meninggal    Tahun_Lahir           Umur
# count              143496    143496.000000  143496.000000  143496.000000
# unique                  3              NaN            NaN            NaN
# top                 AKTIF              NaN            NaN            NaN
# freq               135730              NaN            NaN            NaN
# first                 NaN              NaN            NaN            NaN
# last                  NaN              NaN            NaN            NaN
# mean                  NaN       144.512864    1961.257763      58.711978
# std                   NaN       520.550492      10.243017      10.236496
# min                   NaN         0.000000    1899.000000       2.000000
# 25%                   NaN         0.000000    1954.000000      52.000000
# 50%                   NaN         0.000000    1961.000000      59.000000
# 75%                   NaN         0.000000    1968.000000      65.000000
# max                   NaN      2020.000000    2018.000000     121.000000

# %% [markdown]
# #### 1.1.2. Tahun 2020

# %%
df_20.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_20.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in DM2020_kepesertaan.dta')
df_20.head()
# Out:
# Data in DM2020_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       66897393        66897393            1955-12-31           PESERTA
# 1       36947751        36947751            1957-01-01           PESERTA
# 2       58468881        58468881            1959-06-15           PESERTA
# 3       67318251        67318251            1977-11-11           PESERTA
# 4       80155656        80155656            1961-12-31           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             CERAI    KELAS II            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     PEREMPUAN             KAWIN     KELAS I  BUKAN PEKERJA
# 3     LAKI-LAKI             KAWIN    KELAS II            PPU
# 4     PEREMPUAN             CERAI     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                            ACEH                           KOTA LANGSA
# 3                            ACEH                      KOTA LHOKSEUMAWE
# 4                            ACEH                               BIREUEN
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0                     SWASTA  KLINIK PRATAMA                    ACEH
# 1                     SWASTA     DOKTER UMUM                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.318326          2020              AKTIF
# 1               KOTA BANDA ACEH   1.850896          2020              AKTIF
# 2                   KOTA LANGSA   7.597364          2020              AKTIF
# 3              KOTA LHOKSEUMAWE   6.003162          2020              AKTIF
# 4                       BIREUEN  11.383931          2020              AKTIF
#
#    Tahun_Meninggal
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_20.shape
# Out:
# (143496, 18)

# %%
df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Nomor_Peserta                          143496 non-null  int32
#  1   Nomor_Keluarga                         143496 non-null  int32
#  2   Tanggal_Lahir_Peserta                  143496 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      143496 non-null  category
#  4   Jenis_Kelamin                          143496 non-null  category
#  5   Status_Perkawinan                      143496 non-null  category
#  6   Kelas_Rawat                            143496 non-null  category
#  7   Segmen_Peserta                         143496 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        143496 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  143496 non-null  category
#  10  Kepemilikan_Faskes                     143496 non-null  category
#  11  Jenis_Faskes                           143496 non-null  category
#  12  Provinsi_Faskes_Peserta                143496 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          143496 non-null  category
#  14  Bobot                                  143496 non-null  float32
#  15  Tahun_Sampel                           143496 non-null  int16
#  16  Status_Kepesertaan                     143496 non-null  category
#  17  Tahun_Meninggal                        10268 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 7.2 MB

# %%
df_20.duplicated().sum()
# Out:
# 0

# %%
df_20.isna().sum().sum()
# Out:
# 133228

# %%
df_20.isna().sum()
# Out:
# Nomor_Peserta                                 0
# Nomor_Keluarga                                0
# Tanggal_Lahir_Peserta                         0
# Hubungan_Keluarga                             0
# Jenis_Kelamin                                 0
# Status_Perkawinan                             0
# Kelas_Rawat                                   0
# Segmen_Peserta                                0
# Provinsi_Tempat_Tinggal_Peserta               0
# Kabupaten_Kota_Tempat_Tinggal_Peserta         0
# Kepemilikan_Faskes                            0
# Jenis_Faskes                                  0
# Provinsi_Faskes_Peserta                       0
# Kabupaten_Kota_Faskes_Peserta                 0
# Bobot                                         0
# Tahun_Sampel                                  0
# Status_Kepesertaan                            0
# Tahun_Meninggal                          133228
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 133.228.

# %%
df_20['Tahun_Meninggal'] = df_20['Tahun_Meninggal'].fillna(0).astype(int)
df_20['Tahun_Lahir'] = df_20['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_20['Tahun_Meninggal'] != 0,
                df_20['Tahun_Meninggal'] - df_20['Tahun_Lahir'],
                df_20['Tahun_Sampel'] - df_20['Tahun_Lahir'])
df_20['Umur'] = umur.astype(int)

# %%
df_20.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       66897393        66897393            1955-12-31           PESERTA
# 1       36947751        36947751            1957-01-01           PESERTA
# 2       58468881        58468881            1959-06-15           PESERTA
# 3       67318251        67318251            1977-11-11           PESERTA
# 4       80155656        80155656            1961-12-31           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             CERAI    KELAS II            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     PEREMPUAN             KAWIN     KELAS I  BUKAN PEKERJA
# 3     LAKI-LAKI             KAWIN    KELAS II            PPU
# 4     PEREMPUAN             CERAI     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                            ACEH                           KOTA LANGSA
# 3                            ACEH                      KOTA LHOKSEUMAWE
# 4                            ACEH                               BIREUEN
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0                     SWASTA  KLINIK PRATAMA                    ACEH
# 1                     SWASTA     DOKTER UMUM                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.318326          2020              AKTIF
# 1               KOTA BANDA ACEH   1.850896          2020              AKTIF
# 2                   KOTA LANGSA   7.597364          2020              AKTIF
# 3              KOTA LHOKSEUMAWE   6.003162          2020              AKTIF
# 4                       BIREUEN  11.383931          2020              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0                0         1955    65
# 1                0         1957    63
# 2                0         1959    61
# 3                0         1977    43
# 4                0         1961    59

# %%
df_20.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    1.434960e+05    1.434960e+05                143496            143496
# unique            NaN             NaN                 18552                 5
# top               NaN             NaN   1960-12-31 00:00:00           PESERTA
# freq              NaN             NaN                   441             85514
# first             NaN             NaN   1899-12-30 00:00:00               NaN
# last              NaN             NaN   2018-06-12 00:00:00               NaN
# mean     1.015970e+08    1.216283e+08                   NaN               NaN
# std      1.209830e+08    1.363905e+08                   NaN               NaN
# min      9.680000e+02    5.170000e+02                   NaN               NaN
# 25%      3.011237e+07    3.239370e+07                   NaN               NaN
# 50%      5.977754e+07    6.482657e+07                   NaN               NaN
# 75%      8.989074e+07    9.736831e+07                   NaN               NaN
# max      4.553888e+08    4.553888e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count         143496            143496      143496         143496
# unique             2                 3           4              6
# top        PEREMPUAN             KAWIN   KELAS III           PBPU
# freq           85829            119992       60800          42256
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                           143496                                143496
# unique                              35                                   484
# top                         JAWA TIMUR                         KOTA SURABAYA
# freq                             23450                                  3895
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                      143496       143496                  143496
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        84426        86105                   23514
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta          Bobot  Tahun_Sampel  \
# count                         143496  143496.000000      143496.0
# unique                           488            NaN           NaN
# top                    KOTA SURABAYA            NaN           NaN
# freq                            4098            NaN           NaN
# first                            NaN            NaN           NaN
# last                             NaN            NaN           NaN
# mean                             NaN      10.004865        2020.0
# std                              NaN       3.666396           0.0
# min                              NaN       0.351047        2020.0
# 25%                              NaN       8.047610        2020.0
# 50%                              NaN      11.459408        2020.0
# 75%                              NaN      12.782674        2020.0
# max                              NaN      38.295937        2020.0
#
#        Status_Kepesertaan  Tahun_Meninggal    Tahun_Lahir           Umur
# count              143496    143496.000000  143496.000000  143496.000000
# unique                  3              NaN            NaN            NaN
# top                 AKTIF              NaN            NaN            NaN
# freq               124477              NaN            NaN            NaN
# first                 NaN              NaN            NaN            NaN
# last                  NaN              NaN            NaN            NaN
# mean                  NaN       144.512864    1961.257763      58.711978
# std                   NaN       520.550492      10.243017      10.236496
# min                   NaN         0.000000    1899.000000       2.000000
# 25%                   NaN         0.000000    1954.000000      52.000000
# 50%                   NaN         0.000000    1961.000000      59.000000
# 75%                   NaN         0.000000    1968.000000      65.000000
# max                   NaN      2020.000000    2018.000000     121.000000

# %% [markdown]
# #### 1.1.3. Tahun 2021

# %%
df_21.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV03', 'PSTV04', 'PSTV05', 'PSTV06', 'PSTV07',
#        'PSTV08', 'PSTV09', 'PSTV10', 'PSTV11', 'PSTV12', 'PSTV13', 'PSTV14',
#        'PSTV15', 'PSTV16', 'PSTV17', 'PSTV18'],
#       dtype='object')

# %%
df_21.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV03': 'Tanggal_Lahir_Peserta',
    'PSTV04': 'Hubungan_Keluarga',
    'PSTV05': 'Jenis_Kelamin',
    'PSTV06': 'Status_Perkawinan',
    'PSTV07': 'Kelas_Rawat',
    'PSTV08': 'Segmen_Peserta',
    'PSTV09': 'Provinsi_Tempat_Tinggal_Peserta',
    'PSTV10': 'Kabupaten_Kota_Tempat_Tinggal_Peserta',
    'PSTV11': 'Kepemilikan_Faskes',
    'PSTV12': 'Jenis_Faskes',
    'PSTV13': 'Provinsi_Faskes_Peserta',
    'PSTV14': 'Kabupaten_Kota_Faskes_Peserta',
    'PSTV15': 'Bobot',
    'PSTV16': 'Tahun_Sampel',
    'PSTV17': 'Status_Kepesertaan',
    'PSTV18': 'Tahun_Meninggal'
}, inplace=True)

# %%
print('\nData in DM2021_kepesertaan.dta')
df_21.head()
# Out:
# Data in DM2021_kepesertaan.dta
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       66897393        66897393            1955-12-31           PESERTA
# 1       36947751        36947751            1957-01-01           PESERTA
# 2       58468881        58468881            1959-06-15           PESERTA
# 3       67318251        67318251            1977-11-11           PESERTA
# 4       80155656        80155656            1961-12-31           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             CERAI    KELAS II            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     PEREMPUAN             KAWIN     KELAS I  BUKAN PEKERJA
# 3     LAKI-LAKI             KAWIN    KELAS II            PPU
# 4     PEREMPUAN             CERAI     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                            ACEH                           KOTA LANGSA
# 3                            ACEH                      KOTA LHOKSEUMAWE
# 4                            ACEH                               BIREUEN
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0                     SWASTA  KLINIK PRATAMA                    ACEH
# 1                     SWASTA     DOKTER UMUM                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.318326          2021              AKTIF
# 1               KOTA BANDA ACEH   1.850896          2021              AKTIF
# 2                   KOTA LANGSA   7.597364          2021              AKTIF
# 3              KOTA LHOKSEUMAWE   6.003162          2021              AKTIF
# 4                       BIREUEN  11.383931          2021              AKTIF
#
#    Tahun_Meninggal
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df_21.shape
# Out:
# (143496, 18)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143496 entries, 0 to 143495
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Nomor_Peserta                          143496 non-null  int32
#  1   Nomor_Keluarga                         143496 non-null  int32
#  2   Tanggal_Lahir_Peserta                  143496 non-null  datetime64[ns]
#  3   Hubungan_Keluarga                      143496 non-null  category
#  4   Jenis_Kelamin                          143496 non-null  category
#  5   Status_Perkawinan                      143496 non-null  category
#  6   Kelas_Rawat                            143496 non-null  category
#  7   Segmen_Peserta                         143496 non-null  category
#  8   Provinsi_Tempat_Tinggal_Peserta        143496 non-null  category
#  9   Kabupaten_Kota_Tempat_Tinggal_Peserta  143496 non-null  category
#  10  Kepemilikan_Faskes                     143496 non-null  category
#  11  Jenis_Faskes                           143496 non-null  category
#  12  Provinsi_Faskes_Peserta                143496 non-null  category
#  13  Kabupaten_Kota_Faskes_Peserta          143496 non-null  category
#  14  Bobot                                  143496 non-null  float32
#  15  Tahun_Sampel                           143496 non-null  int16
#  16  Status_Kepesertaan                     143496 non-null  category
#  17  Tahun_Meninggal                        17679 non-null   float64
# dtypes: category(12), datetime64[ns](1), float32(1), float64(1), int16(1), int32(2)
# memory usage: 7.2 MB

# %%
df_21.duplicated().sum()
# Out:
# 0

# %%
df_21.isna().sum().sum()
# Out:
# 125817

# %%
df_21.isna().sum()
# Out:
# Nomor_Peserta                                 0
# Nomor_Keluarga                                0
# Tanggal_Lahir_Peserta                         0
# Hubungan_Keluarga                             0
# Jenis_Kelamin                                 0
# Status_Perkawinan                             0
# Kelas_Rawat                                   0
# Segmen_Peserta                                0
# Provinsi_Tempat_Tinggal_Peserta               0
# Kabupaten_Kota_Tempat_Tinggal_Peserta         0
# Kepemilikan_Faskes                            0
# Jenis_Faskes                                  0
# Provinsi_Faskes_Peserta                       0
# Kabupaten_Kota_Faskes_Peserta                 0
# Bobot                                         0
# Tahun_Sampel                                  0
# Status_Kepesertaan                            0
# Tahun_Meninggal                          125817
# dtype: int64

# %% [markdown]
# - Jumlah missing value pada fitur `Tahun_Meninggal` sebanyak 125.817.

# %%
df_21['Tahun_Meninggal'] = df_21['Tahun_Meninggal'].fillna(0).astype(int)
df_21['Tahun_Lahir'] = df_21['Tanggal_Lahir_Peserta'].dt.year

umur = np.where(df_21['Tahun_Meninggal'] != 0,
                df_21['Tahun_Meninggal'] - df_21['Tahun_Lahir'],
                df_21['Tahun_Sampel'] - df_21['Tahun_Lahir'])
df_21['Umur'] = umur.astype(int)

# %%
df_21.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# 0       66897393        66897393            1955-12-31           PESERTA
# 1       36947751        36947751            1957-01-01           PESERTA
# 2       58468881        58468881            1959-06-15           PESERTA
# 3       67318251        67318251            1977-11-11           PESERTA
# 4       80155656        80155656            1961-12-31           PESERTA
#
#   Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# 0     LAKI-LAKI             CERAI    KELAS II            PPU
# 1     LAKI-LAKI             KAWIN     KELAS I  BUKAN PEKERJA
# 2     PEREMPUAN             KAWIN     KELAS I  BUKAN PEKERJA
# 3     LAKI-LAKI             KAWIN    KELAS II            PPU
# 4     PEREMPUAN             CERAI     KELAS I            PPU
#
#   Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# 0                            ACEH                                 PIDIE
# 1                            ACEH                       KOTA BANDA ACEH
# 2                            ACEH                           KOTA LANGSA
# 3                            ACEH                      KOTA LHOKSEUMAWE
# 4                            ACEH                               BIREUEN
#
#           Kepemilikan_Faskes    Jenis_Faskes Provinsi_Faskes_Peserta  \
# 0                     SWASTA  KLINIK PRATAMA                    ACEH
# 1                     SWASTA     DOKTER UMUM                    ACEH
# 2  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 3  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
# 4  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS                    ACEH
#
#   Kabupaten_Kota_Faskes_Peserta      Bobot  Tahun_Sampel Status_Kepesertaan  \
# 0                         PIDIE  11.318326          2021              AKTIF
# 1               KOTA BANDA ACEH   1.850896          2021              AKTIF
# 2                   KOTA LANGSA   7.597364          2021              AKTIF
# 3              KOTA LHOKSEUMAWE   6.003162          2021              AKTIF
# 4                       BIREUEN  11.383931          2021              AKTIF
#
#    Tahun_Meninggal  Tahun_Lahir  Umur
# 0                0         1955    66
# 1                0         1957    64
# 2                0         1959    62
# 3                0         1977    44
# 4                0         1961    60

# %%
df_21.describe(include='all')
# Out:
#         Nomor_Peserta  Nomor_Keluarga Tanggal_Lahir_Peserta Hubungan_Keluarga  \
# count    1.434960e+05    1.434960e+05                143496            143496
# unique            NaN             NaN                 18552                 5
# top               NaN             NaN   1960-12-31 00:00:00           PESERTA
# freq              NaN             NaN                   441             86276
# first             NaN             NaN   1899-12-30 00:00:00               NaN
# last              NaN             NaN   2018-06-12 00:00:00               NaN
# mean     1.015970e+08    1.216283e+08                   NaN               NaN
# std      1.209830e+08    1.363905e+08                   NaN               NaN
# min      9.680000e+02    5.170000e+02                   NaN               NaN
# 25%      3.011237e+07    3.239370e+07                   NaN               NaN
# 50%      5.977754e+07    6.482657e+07                   NaN               NaN
# 75%      8.989074e+07    9.736831e+07                   NaN               NaN
# max      4.553888e+08    4.553888e+08                   NaN               NaN
#
#        Jenis_Kelamin Status_Perkawinan Kelas_Rawat Segmen_Peserta  \
# count         143496            143496      143496         143496
# unique             2                 3           4              6
# top        PEREMPUAN             KAWIN   KELAS III           PBPU
# freq           85829            119606       61732          41650
# first            NaN               NaN         NaN            NaN
# last             NaN               NaN         NaN            NaN
# mean             NaN               NaN         NaN            NaN
# std              NaN               NaN         NaN            NaN
# min              NaN               NaN         NaN            NaN
# 25%              NaN               NaN         NaN            NaN
# 50%              NaN               NaN         NaN            NaN
# 75%              NaN               NaN         NaN            NaN
# max              NaN               NaN         NaN            NaN
#
#        Provinsi_Tempat_Tinggal_Peserta Kabupaten_Kota_Tempat_Tinggal_Peserta  \
# count                           143496                                143496
# unique                              35                                   487
# top                         JAWA TIMUR                         KOTA SURABAYA
# freq                             23463                                  3887
# first                              NaN                                   NaN
# last                               NaN                                   NaN
# mean                               NaN                                   NaN
# std                                NaN                                   NaN
# min                                NaN                                   NaN
# 25%                                NaN                                   NaN
# 50%                                NaN                                   NaN
# 75%                                NaN                                   NaN
# max                                NaN                                   NaN
#
#                Kepemilikan_Faskes Jenis_Faskes Provinsi_Faskes_Peserta  \
# count                      143496       143496                  143496
# unique                          9            3                      34
# top     PEMERINTAH KABUPATEN/KOTA    PUSKESMAS              JAWA TIMUR
# freq                        84974        86622                   23567
# first                         NaN          NaN                     NaN
# last                          NaN          NaN                     NaN
# mean                          NaN          NaN                     NaN
# std                           NaN          NaN                     NaN
# min                           NaN          NaN                     NaN
# 25%                           NaN          NaN                     NaN
# 50%                           NaN          NaN                     NaN
# 75%                           NaN          NaN                     NaN
# max                           NaN          NaN                     NaN
#
#        Kabupaten_Kota_Faskes_Peserta          Bobot  Tahun_Sampel  \
# count                         143496  143496.000000      143496.0
# unique                           486            NaN           NaN
# top                    KOTA SURABAYA            NaN           NaN
# freq                            4074            NaN           NaN
# first                            NaN            NaN           NaN
# last                             NaN            NaN           NaN
# mean                             NaN      10.004865        2021.0
# std                              NaN       3.666396           0.0
# min                              NaN       0.351047        2021.0
# 25%                              NaN       8.047610        2021.0
# 50%                              NaN      11.459408        2021.0
# 75%                              NaN      12.782674        2021.0
# max                              NaN      38.295937        2021.0
#
#        Status_Kepesertaan  Tahun_Meninggal    Tahun_Lahir           Umur
# count              143496    143496.000000  143496.000000  143496.000000
# unique                  4              NaN            NaN            NaN
# top                 AKTIF              NaN            NaN            NaN
# freq               113005              NaN            NaN            NaN
# first                 NaN              NaN            NaN            NaN
# last                  NaN              NaN            NaN            NaN
# mean                  NaN       248.889648    1961.257763      59.640561
# std                   NaN       663.971137      10.243017      10.224047
# min                   NaN         0.000000    1899.000000       3.000000
# 25%                   NaN         0.000000    1954.000000      53.000000
# 50%                   NaN         0.000000    1961.000000      60.000000
# 75%                   NaN         0.000000    1968.000000      66.000000
# max                   NaN      2021.000000    2018.000000     122.000000

# %% [markdown]
# ### 1.2. Fasilitas Kesehatan Tingkat Pratama (FKTP) Kapitasi

# %%
df_fktp_k.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKP03', 'FKP04', 'FKP05',
#        'FKP06', 'FKP07', 'FKP08', 'FKP09', 'FKP10', 'FKP11', 'FKP12', 'FKP13',
#        'FKP14', 'FKP14A', 'FKP15', 'FKP15A', 'FKP16', 'FKP17', 'FKP18',
#        'FKP19', 'FKP20', 'FKP21', 'FKP22'],
#       dtype='object')

# %%
df_fktp_k.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'FKP02' : 'ID_Kunjungan_FKTP',
    'FKP03' : 'Tanggal_Datang_Kunjungan',
    'FKP04' : 'Tanggal_Pulang_Kunjungan',
    'FKP05' : 'Provinsi',
    'FKP06' : 'Kabupaten_Kota',
    'FKP07' : 'Kepemilikan',
    'FKP08' : 'Jenis',
    'FKP09' : 'Tipe',
    'FKP10' : 'Tingkat_Pelayanan',
    'FKP11' : 'Jenis_Poli',
    'FKP12' : 'Segmen_Peserta_Akses_Layanan',
    'FKP13' : 'Status_Pulang_Peserta',
    'FKP14' : 'Kode_Nama_Diagnosis_ICD_10_FKP',
    'FKP14A': 'Kode_Diagnosis_ICD_10_FKP',
    'FKP15' : 'Kode_Diagnosis_3_5_Digit_FKP',
    'FKP15A': 'Nama_Diagnosis_Dari_Kode_Diagnosis_FKP15',
    'FKP16' : 'Provinsi_Faskes_Tujuan_Rujukan',
    'FKP17' : 'Kabupaten_Kota_Faskes_Tujuan_Rujukan',
    'FKP18' : 'Kepemilikan_Faskes_Tujuan_Rujukan',
    'FKP19' : 'Jenis_Faskes_Tujuan_Rujukan',
    'FKP20' : 'Tipe_Faskes_Tujuan_Rujukan',
    'FKP21' : 'Poli_Faskes_Tujuan_Rujukan',
    'FKP22' : 'Jenis_Kunjungan'
}, inplace=True)

# %%
df_fktp_k.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga      Bobot ID_Kunjungan_FKTP  \
# 0       12380560        12380560  13.364630        1687160334
# 1      288452470        78043385   8.494392        1457720536
# 2      337885189       337885189  13.472825        1732989007
# 3        2783323         2783323  12.233603        1464029376
# 4       99122276         6688304   6.842236        1646802901
#
#   Tanggal_Datang_Kunjungan Tanggal_Pulang_Kunjungan  Provinsi  Kabupaten_Kota  \
# 0               2021-11-10               2021-11-10        31            3174
# 1               2021-02-26               2021-02-26        17            1702
# 2               2021-12-08               2021-12-08        31            3175
# 3               2021-03-03               2021-03-03        32            3276
# 4               2021-09-28               2021-09-28        52            5272
#
#    Kepemilikan  Jenis  Tipe  Tingkat_Pelayanan  Jenis_Poli  \
# 0            3      1     3                  1          13
# 1            3      1     3                  1          12
# 2            3      1     3                  1          13
# 3            3      1     4                  1          13
# 4            3      1     4                  1          12
#
#    Segmen_Peserta_Akses_Layanan  Status_Pulang_Peserta  \
# 0                             3                     98
# 1                             5                     98
# 2                             3                     98
# 3                             4                     98
# 4                             5                     98
#
#    Kode_Nama_Diagnosis_ICD_10_FKP Kode_Diagnosis_ICD_10_FKP  \
# 0                            9999
# 1                            9999
# 2                            9999
# 3                            9999
# 4                            9999
#
#   Kode_Diagnosis_3_5_Digit_FKP Nama_Diagnosis_Dari_Kode_Diagnosis_FKP15  \
# 0                         9999                                     9999
# 1                         9999                                     9999
# 2                         9999                                     9999
# 3                         9999                                     9999
# 4                         9999                                     9999
#
#    Provinsi_Faskes_Tujuan_Rujukan  Kabupaten_Kota_Faskes_Tujuan_Rujukan  \
# 0                              98                                  9998
# 1                              98                                  9998
# 2                              98                                  9998
# 3                              98                                  9998
# 4                              98                                  9998
#
#    Kepemilikan_Faskes_Tujuan_Rujukan  Jenis_Faskes_Tujuan_Rujukan  \
# 0                                 98                           98
# 1                                 98                           98
# 2                                 98                           98
# 3                                 98                           98
# 4                                 98                           98
#
#    Tipe_Faskes_Tujuan_Rujukan  Poli_Faskes_Tujuan_Rujukan  Jenis_Kunjungan
# 0                          98                          98                2
# 1                          98                          98                2
# 2                          98                          98                2
# 3                          98                          98                2
# 4                          98                          98                2

# %%
df_fktp_k.shape
# Out:
# (1188324, 26)

# %%
df_fktp_k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1188324 entries, 0 to 1188323
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   Nomor_Peserta                             1188324 non-null  int32
#  1   Nomor_Keluarga                            1188324 non-null  int32
#  2   Bobot                                     1188324 non-null  float32
#  3   ID_Kunjungan_FKTP                         1188324 non-null  object
#  4   Tanggal_Datang_Kunjungan                  1188324 non-null  datetime64[ns]
#  5   Tanggal_Pulang_Kunjungan                  1188324 non-null  datetime64[ns]
#  6   Provinsi                                  1188324 non-null  int8
#  7   Kabupaten_Kota                            1188324 non-null  int16
#  8   Kepemilikan                               1188324 non-null  int8
#  9   Jenis                                     1188324 non-null  int8
#  10  Tipe                                      1188324 non-null  int8
#  11  Tingkat_Pelayanan                         1188324 non-null  int8
#  12  Jenis_Poli                                1188324 non-null  int8
#  13  Segmen_Peserta_Akses_Layanan              1188324 non-null  int8
#  14  Status_Pulang_Peserta                     1188324 non-null  int8
#  15  Kode_Nama_Diagnosis_ICD_10_FKP            1188324 non-null  int16
#  16  Kode_Diagnosis_ICD_10_FKP                 1188324 non-null  object
#  17  Kode_Diagnosis_3_5_Digit_FKP              1188324 non-null  object
#  18  Nama_Diagnosis_Dari_Kode_Diagnosis_FKP15  1188324 non-null  object
#  19  Provinsi_Faskes_Tujuan_Rujukan            1188324 non-null  int8
#  20  Kabupaten_Kota_Faskes_Tujuan_Rujukan      1188324 non-null  int16
#  21  Kepemilikan_Faskes_Tujuan_Rujukan         1188324 non-null  int8
#  22  Jenis_Faskes_Tujuan_Rujukan               1188324 non-null  int8
#  23  Tipe_Faskes_Tujuan_Rujukan                1188324 non-null  int8
#  24  Poli_Faskes_Tujuan_Rujukan                1188324 non-null  int16
#  25  Jenis_Kunjungan                           1188324 non-null  int8
# dtypes: datetime64[ns](2), float32(1), int16(4), int32(2), int8(13), object(4)
# memory usage: 100.9+ MB

# %%
df_fktp_k.duplicated().sum()
# Out:
# 0

# %%
df_fktp_k.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 1.3. Fasilitas Kesehatan Rujukan Tingkat Lanjutan (FKRTL) Diagnosis Primer

# %%
df_fkrtl_1.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'FKP02', 'FKL02', 'FKL03', 'FKL04',
#        'FKL05', 'FKL06', 'FKL07', 'FKL08', 'FKL09', 'FKL10', 'FKL11', 'FKL12',
#        'FKL13', 'FKL14', 'FKL15', 'FKL15A', 'FKL16', 'FKL16A', 'FKL17',
#        'FKL17A', 'FKL18', 'FKL18A', 'FKL19', 'FKL19A', 'FKL20', 'FKL21',
#        'FKL22', 'FKL23', 'FKL25', 'FKL26', 'FKL27', 'FKL28', 'FKL29', 'FKL30',
#        'FKL31', 'FKL32', 'FKL33', 'FKL34', 'FKL35', 'FKL36', 'FKL37', 'FKL38',
#        'FKL39', 'FKL40', 'FKL41', 'FKL42', 'FKL43', 'FKL44', 'FKL45', 'FKL46',
#        'FKL47', 'FKL48'],
#       dtype='object')

# %%
df_fkrtl_1.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'FKP02' : 'ID_Kunjungan_FKTP',
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL03' : 'Tanggal_Datang_Kunjungan',
    'FKL04' : 'Tanggal_Pulang_Kunjungan',
    'FKL05' : 'Provinsi',
    'FKL06' : 'Kabupaten_Kota',
    'FKL07' : 'Kepemilikan',
    'FKL08' : 'Jenis',
    'FKL09' : 'Tipe',
    'FKL10' : 'Tingkat_Pelayanan',
    'FKL11' : 'Jenis_Poli',
    'FKL12' : 'Segmen_Peserta_Akses_Layanan',
    'FKL13' : 'Kelas_Rawat_Peserta',
    'FKL14' : 'Status_Pulang',
    'FKL15' : 'Kode_Nama_Diagnosis_Masuk_ICD_10',
    'FKL15A': 'Kode_Diagnosis_Masuk_ICD_10',
    'FKL16' : 'Kode_ICD_10_Diagnosis_Masuk',
    'FKL16A': 'Nama_Diagnosis_Masuk',
    'FKL17' : 'Kode_Nama_Diagnosis_Primer_ICD_10',
    'FKL17A': 'Kode_Diagnosis_Primer_ICD_10',
    'FKL18' : 'Kode_ICD_10_Diagnosis_Primer',
    'FKL18A': 'Nama_Diagnosis_Primer',
    'FKL19' : 'Kode_INACBGs',
    'FKL19A': 'Deskripsi_Kode_INACBGs',
    'FKL20' : 'INACBGs_Kode_Casemix_Main_Groups',
    'FKL21' : 'INACBGs_Tipe_Kelompok_Kasus',
    'FKL22' : 'INACBGs_Spesifikasi_Kelompok_Kasus',
    'FKL23' : 'INACBGs_Tingkat_Keparahan_Kelompok_Kasus',
    'FKL25' : 'Provinsi_Faskes_Perujuk',
    'FKL26' : 'Kabupaten_Kota_Faskes_Perujuk',
    'FKL27' : 'Kepemilikan_Faskes_Perujuk',
    'FKL28' : 'Jenis_Faskes_Perujuk',
    'FKL29' : 'Tipe_Faskes_Perujuk',
    'FKL30' : 'Jenis_Prosedur',
    'FKL31' : 'Tarif_Regional_INACBGs',
    'FKL32' : 'Group_Tarif_INACBGs',
    'FKL33' : 'Kode_Special_Sub-Acute_Groups_SA',
    'FKL34' : 'Tarif_Special_Sub-Acute_Groups_SA',
    'FKL35' : 'Kode_Special_Procedures_SP',
    'FKL36' : 'Deskripsi_Special_Procedures_SP',
    'FKL37' : 'Tarif_Special_Procedures_SP',
    'FKL38' : 'Kode_Special_Prosthesis_RR',
    'FKL39' : 'Deskripsi_Special_Prosthesis_RR',
    'FKL40' : 'Tarif_Special_Prosthesis_RR',
    'FKL41' : 'Kode_Special_Investigation_SI',
    'FKL42' : 'Deskripsi_Special_Investigation_SI',
    'FKL43' : 'Tarif_Special_Investigation_SI',
    'FKL44' : 'Kode_Special_Drugs_SD',
    'FKL45' : 'Deskripsi_Special_Drugs_SD',
    'FKL46' : 'Tarif_Special_Drugs_SD',
    'FKL47' : 'Biaya_Tagih_Faskes_Provider',
    'FKL48' : 'Biaya_Verifikasi'
}, inplace=True)

# %%
df_fkrtl_1.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga      Bobot ID_Kunjungan_FKTP  \
# 0       50886719        50886719  12.507828
# 1       70972186         6871133  13.055749
# 2       31874094        71865092   7.740489
# 3       87945875        87945875   7.734398
# 4      384677503       384677503   2.777775
#
#   ID_Kunjungan_FKRTL Tanggal_Datang_Kunjungan Tanggal_Pulang_Kunjungan  \
# 0   414390221V002006               2021-02-20               2021-02-20
# 1   380700421V000216               2021-04-07               2021-04-08
# 2   385450421V006571               2021-04-19               2021-04-19
# 3   206900221V006045               2021-02-28               2021-03-03
# 4   447120121V000468               2021-01-29               2021-02-01
#
#            Provinsi   Kabupaten_Kota          Kepemilikan        Jenis  \
# 0              RIAU   KOTA PEKANBARU                POLRI  Rumah sakit
# 1  KALIMANTAN TIMUR   KOTA SAMARINDA               TNI AD  Rumah sakit
# 2       JAWA TENGAH   KOTA SURAKARTA               Swasta  Rumah sakit
# 3              ACEH      ACEH TENGAH  Pemerintah kab/kota  Rumah sakit
# 4  SUMATERA SELATAN  KOTA PRABUMULIH               Swasta  Rumah sakit
#
#                       Tipe Tingkat_Pelayanan Jenis_Poli  \
# 0   RS TNI Polri Kelas III              RJTL        IGD
# 1    RS TNI Polri Kelas IV              RITL    Missing
# 2  RS Swasta Setara Type B              RJTL        IGD
# 3               RS Kelas B              RITL    Missing
# 4  RS Swasta Setara Type D              RITL    Missing
#
#   Segmen_Peserta_Akses_Layanan Kelas_Rawat_Peserta Status_Pulang  \
# 0                         PBPU             Kelas 3         Sehat
# 1                         PBPU             Kelas 2         Sehat
# 2                          PPU             Kelas 3         Sehat
# 3                     PBI APBD             Kelas 3         Sehat
# 4                         PBPU             Kelas 3         Sehat
#
#                     Kode_Nama_Diagnosis_Masuk_ICD_10  \
# 0                                        A00 Cholera
# 1                     R06 Abnormalities of breathing
# 2                                       R51 Headache
# 3  J10 Influenza due to other identified influenz...
# 4              R50 Fever of other and unknown origin
#
#   Kode_Diagnosis_Masuk_ICD_10 Kode_ICD_10_Diagnosis_Masuk  \
# 0                         A00                        A009
# 1                         R06                        R060
# 2                         R51                         R51
# 3                         J10                        J108
# 4                         R50                        R509
#
#                                 Nama_Diagnosis_Masuk  \
# 0                               Cholera, unspecified
# 1                                           Dyspnoea
# 2                                           Headache
# 3  Influenza with other manifestations, influenza...
# 4                                 Fever, unspecified
#
#     Kode_Nama_Diagnosis_Primer_ICD_10 Kode_Diagnosis_Primer_ICD_10  \
# 0                         A00 Cholera                          A00
# 1  A01 Typhoid and paratyphoid fevers                          A01
# 2  A01 Typhoid and paratyphoid fevers                          A01
# 3  A01 Typhoid and paratyphoid fevers                          A01
# 4  A01 Typhoid and paratyphoid fevers                          A01
#
#   Kode_ICD_10_Diagnosis_Primer Nama_Diagnosis_Primer Kode_INACBGs  \
# 0                         A009  Cholera, unspecified     Q-5-42-0
# 1                         A010         Typhoid fever     A-4-14-I
# 2                         A010         Typhoid fever     Q-5-42-0
# 3                         A010         Typhoid fever    A-4-14-II
# 4                         A010         Typhoid fever     A-4-14-I
#
#                               Deskripsi_Kode_INACBGs  \
# 0                      PENYAKIT AKUT KECIL LAIN-LAIN
# 1  PENYAKIT INFEKSI BAKTERI DAN  PARASIT LAIN-LAI...
# 2                      PENYAKIT AKUT KECIL LAIN-LAIN
# 3  PENYAKIT INFEKSI BAKTERI DAN  PARASIT LAIN-LAI...
# 4  PENYAKIT INFEKSI BAKTERI DAN  PARASIT LAIN-LAI...
#
#           INACBGs_Kode_Casemix_Main_Groups INACBGs_Tipe_Kelompok_Kasus  \
# 0            Q. Ambulatory Groups-Episodic  Rawat Jalan Bukan Prosedur
# 1  A. Infectious & parasitic diseases Grou   Rawat Inap Bukan Prosedur
# 2            Q. Ambulatory Groups-Episodic  Rawat Jalan Bukan Prosedur
# 3  A. Infectious & parasitic diseases Grou   Rawat Inap Bukan Prosedur
# 4  A. Infectious & parasitic diseases Grou   Rawat Inap Bukan Prosedur
#
#    INACBGs_Spesifikasi_Kelompok_Kasus  \
# 0                                  42
# 1                                  14
# 2                                  42
# 3                                  14
# 4                                  14
#
#   INACBGs_Tingkat_Keparahan_Kelompok_Kasus Provinsi_Faskes_Perujuk  \
# 0                              Rawat Jalan                    RIAU
# 1          Ringan (rawat inap keparahan 1)        KALIMANTAN TIMUR
# 2                              Rawat Jalan             JAWA TENGAH
# 3          Sedang (rawat inap keparahan 2)                    ACEH
# 4          Ringan (rawat inap keparahan 1)        SUMATERA SELATAN
#
#   Kabupaten_Kota_Faskes_Perujuk Kepemilikan_Faskes_Perujuk  \
# 0                KOTA PEKANBARU                      POLRI
# 1                KOTA SAMARINDA                     TNI AD
# 2                   KARANGANYAR                     Swasta
# 3                   ACEH TENGAH                     PemKab
# 4               KOTA PRABUMULIH                     Swasta
#
#   Jenis_Faskes_Perujuk      Tipe_Faskes_Perujuk  \
# 0       Klinik Pratama    KLINIK NON RAWAT INAP
# 1          Rumah sakit    RS TNI POLRI KELAS IV
# 2       Klinik Pratama        KLINIK RAWAT INAP
# 3          Rumah sakit               RS KELAS B
# 4          Rumah sakit  RS SWASTA SETARA TYPE D
#
#                                       Jenis_Prosedur Tarif_Regional_INACBGs  \
# 0                                                                regional 2
# 1      9059 - Other microscopic examination of blood             regional 4
# 2  8952 - Electrocardiogram;9059 - Other microsco...             regional 1
# 3                           8952 - Electrocardiogram             regional 3
# 4                                                                regional 2
#
#    Group_Tarif_INACBGs Kode_Special_Sub-Acute_Groups_SA  \
# 0               184300
# 1              2578800
# 2               193800
# 3              2705800
# 4              2174700
#
#    Tarif_Special_Sub-Acute_Groups_SA Kode_Special_Procedures_SP  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
#
#   Deskripsi_Special_Procedures_SP  Tarif_Special_Procedures_SP  \
# 0                                                            0
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 4                                                            0
#
#   Kode_Special_Prosthesis_RR Deskripsi_Special_Prosthesis_RR  \
# 0
# 1
# 2
# 3
# 4
#
#    Tarif_Special_Prosthesis_RR Kode_Special_Investigation_SI  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
#
#   Deskripsi_Special_Investigation_SI  Tarif_Special_Investigation_SI  \
# 0                                                                  0
# 1                                                                  0
# 2                                                                  0
# 3                                                                  0
# 4                                                                  0
#
#   Kode_Special_Drugs_SD Deskripsi_Special_Drugs_SD  Tarif_Special_Drugs_SD  \
# 0                                                                        0
# 1                                                                        0
# 2                                                                        0
# 3                                                                        0
# 4                                                                        0
#
#    Biaya_Tagih_Faskes_Provider  Biaya_Verifikasi
# 0                       184300            184300
# 1                      2578800           2578800
# 2                       193800            193800
# 3                      2705800           2705800
# 4                      2174700           2174700

# %%
df_fkrtl_1.shape
# Out:
# (826641, 55)

# %%
df_fkrtl_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 826641 entries, 0 to 826640
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Nomor_Peserta                             826641 non-null  int32
#  1   Nomor_Keluarga                            826641 non-null  int32
#  2   Bobot                                     826641 non-null  float32
#  3   ID_Kunjungan_FKTP                         826641 non-null  object
#  4   ID_Kunjungan_FKRTL                        826641 non-null  object
#  5   Tanggal_Datang_Kunjungan                  826641 non-null  datetime64[ns]
#  6   Tanggal_Pulang_Kunjungan                  826641 non-null  datetime64[ns]
#  7   Provinsi                                  826641 non-null  category
#  8   Kabupaten_Kota                            826641 non-null  category
#  9   Kepemilikan                               826641 non-null  category
#  10  Jenis                                     826641 non-null  category
#  11  Tipe                                      826641 non-null  category
#  12  Tingkat_Pelayanan                         826641 non-null  category
#  13  Jenis_Poli                                826641 non-null  category
#  14  Segmen_Peserta_Akses_Layanan              826641 non-null  category
#  15  Kelas_Rawat_Peserta                       826641 non-null  category
#  16  Status_Pulang                             826641 non-null  category
#  17  Kode_Nama_Diagnosis_Masuk_ICD_10          826641 non-null  category
#  18  Kode_Diagnosis_Masuk_ICD_10               826641 non-null  object
#  19  Kode_ICD_10_Diagnosis_Masuk               826641 non-null  object
#  20  Nama_Diagnosis_Masuk                      826641 non-null  object
#  21  Kode_Nama_Diagnosis_Primer_ICD_10         826641 non-null  category
#  22  Kode_Diagnosis_Primer_ICD_10              826641 non-null  object
#  23  Kode_ICD_10_Diagnosis_Primer              826641 non-null  object
#  24  Nama_Diagnosis_Primer                     826641 non-null  object
#  25  Kode_INACBGs                              826641 non-null  object
#  26  Deskripsi_Kode_INACBGs                    826641 non-null  object
#  27  INACBGs_Kode_Casemix_Main_Groups          826641 non-null  category
#  28  INACBGs_Tipe_Kelompok_Kasus               826641 non-null  category
#  29  INACBGs_Spesifikasi_Kelompok_Kasus        826641 non-null  int8
#  30  INACBGs_Tingkat_Keparahan_Kelompok_Kasus  826641 non-null  category
#  31  Provinsi_Faskes_Perujuk                   826641 non-null  category
#  32  Kabupaten_Kota_Faskes_Perujuk             826641 non-null  category
#  33  Kepemilikan_Faskes_Perujuk                826641 non-null  category
#  34  Jenis_Faskes_Perujuk                      826641 non-null  category
#  35  Tipe_Faskes_Perujuk                       826641 non-null  category
#  36  Jenis_Prosedur                            826641 non-null  object
#  37  Tarif_Regional_INACBGs                    826641 non-null  category
#  38  Group_Tarif_INACBGs                       826641 non-null  int32
#  39  Kode_Special_Sub-Acute_Groups_SA          826641 non-null  object
#  40  Tarif_Special_Sub-Acute_Groups_SA         826641 non-null  int32
#  41  Kode_Special_Procedures_SP                826641 non-null  object
#  42  Deskripsi_Special_Procedures_SP           826641 non-null  object
#  43  Tarif_Special_Procedures_SP               826641 non-null  int32
#  44  Kode_Special_Prosthesis_RR                826641 non-null  object
#  45  Deskripsi_Special_Prosthesis_RR           826641 non-null  object
#  46  Tarif_Special_Prosthesis_RR               826641 non-null  int32
#  47  Kode_Special_Investigation_SI             826641 non-null  object
#  48  Deskripsi_Special_Investigation_SI        826641 non-null  object
#  49  Tarif_Special_Investigation_SI            826641 non-null  int32
#  50  Kode_Special_Drugs_SD                     826641 non-null  object
#  51  Deskripsi_Special_Drugs_SD                826641 non-null  object
#  52  Tarif_Special_Drugs_SD                    826641 non-null  int32
#  53  Biaya_Tagih_Faskes_Provider               826641 non-null  int32
#  54  Biaya_Verifikasi                          826641 non-null  int32
# dtypes: category(21), datetime64[ns](2), float32(1), int32(10), int8(1), object(20)
# memory usage: 200.4+ MB

# %%
df_fkrtl_1.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_1.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 1.4. FKTP Non-Kapitasi

# %%
df_fktp_n.columns
# Out:
# Index(['PSTV01', 'PSTV02', 'PSTV15', 'PNK02', 'PNK03', 'PNK04', 'PNK05',
#        'PNK06', 'PNK07', 'PNK08', 'PNK09', 'PNK10', 'PNK11', 'PNK12', 'PNK13',
#        'PNK13A', 'PNK14', 'PNK15', 'PNK16', 'PNK17', 'PNK18', 'PNK19',
#        'PNK20'],
#       dtype='object')

# %%
df_fktp_n.rename(columns={
    'PSTV01': 'Nomor_Peserta',
    'PSTV02': 'Nomor_Keluarga',
    'PSTV15': 'Bobot',
    'PNK02' : 'ID_Kunjungan',
    'PNK03' : 'Tanggal_Kunjungan',
    'PNK04' : 'Tanggal_Tindakan',
    'PNK05' : 'Tanggal_Pulang',
    'PNK06' : 'Provinsi_Faskes',
    'PNK07' : 'Kode_Kab_Kota_Faskes',
    'PNK08' : 'Kepemilikan_Faskes',
    'PNK09' : 'Jenis_Faskes',
    'PNK10' : 'Tipe_Faskes',
    'PNK11' : 'Tingkat_Layanan',
    'PNK12' : 'Segmen_Peserta',
    'PNK13' : 'Kode_Nama_Diagnosis_ICD_10',
    'PNK13A': 'Kode_Diagnosis_ICD_10',
    'PNK14' : 'Kode_Diagnosis_3_5_Digit',
    'PNK15' : 'Nama_Diagnosis',
    'PNK16' : 'Nama_Tindakan',
    'PNK17' : 'Biaya_Tagih',
    'PNK18' : 'Biaya_Verifikasi',
    'PNK19' : 'Hasil_Pemeriksaan_GDP_1', # Gula Darah Puasa
    'PNK20' : 'Hasil_Pemeriksaan_GDP_2'
}, inplace=True)

# %%
df_fktp_n.head()
# Out:
#    Nomor_Peserta  Nomor_Keluarga      Bobot      ID_Kunjungan  \
# 0       88204825        88204825   6.755007  203960321P000052
# 1       24034617        72462276  12.832207  185630321P001651
# 2       17391573       417758463  13.106908   46631021P000693
# 3       60560444        60560444  12.762736  325900321P000146
# 4      291346266       291346266  13.404066  460570621P000056
#
#   Tanggal_Kunjungan Tanggal_Tindakan Tanggal_Pulang      Provinsi_Faskes  \
# 0        2021-03-13       2021-03-16     2021-03-16  NUSA TENGGARA BARAT
# 1        2021-03-28       2021-03-28     2021-03-30     SULAWESI SELATAN
# 2        2021-10-11       2021-10-14     2021-10-14           JAWA BARAT
# 3        2021-03-17       2021-03-21     2021-03-21          JAWA TENGAH
# 4        2021-06-13       2021-06-16     2021-06-16                 ACEH
#
#   Kode_Kab_Kota_Faskes         Kepemilikan_Faskes    Jenis_Faskes  \
# 0         LOMBOK TIMUR                     SWASTA  KLINIK PRATAMA
# 1                 LUWU  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
# 2              BANDUNG  PEMERINTAH KABUPATEN/KOTA       PUSKESMAS
# 3               SRAGEN                     SWASTA  KLINIK PRATAMA
# 4           ACEH UTARA                     SWASTA  KLINIK PRATAMA
#
#          Tipe_Faskes Tingkat_Layanan Segmen_Peserta  \
# 0  KLINIK RAWAT INAP            RITP       PBI APBN
# 1         RAWAT INAP            RITP       PBI APBN
# 2         RAWAT INAP            RITP       PBI APBN
# 3  KLINIK RAWAT INAP            RITP       PBI APBN
# 4  KLINIK RAWAT INAP            RITP            PPU
#
#                           Kode_Nama_Diagnosis_ICD_10 Kode_Diagnosis_ICD_10  \
# 0                 A01 Typhoid and paratyphoid fevers                   A01
# 1                 A01 Typhoid and paratyphoid fevers                   A01
# 2                 A01 Typhoid and paratyphoid fevers                   A01
# 3  A09 Other gastroenteritis and colitis of infec...                   A09
# 4  A09 Other gastroenteritis and colitis of infec...                   A09
#
#   Kode_Diagnosis_3_5_Digit                                     Nama_Diagnosis  \
# 0                     A010                                      Typhoid fever
# 1                     A010                                      Typhoid fever
# 2                     A010                                      Typhoid fever
# 3                      A09  Diarrhoea and gastroenteritis of presumed infe...
# 4                      A09  Diarrhoea and gastroenteritis of presumed infe...
#
#                       Nama_Tindakan  Biaya_Tagih  Biaya_Verifikasi  \
# 0  Rawat Inap di R. Perawatan Biasa       540000            540000
# 1  Rawat Inap di R. Perawatan Biasa       240000            240000
# 2  Rawat Inap di R. Perawatan Biasa       600000            600000
# 3  Rawat Inap di R. Perawatan Biasa       640000            640000
# 4  Rawat Inap di R. Perawatan Biasa       525000            525000
#
#    Hasil_Pemeriksaan_GDP_1  Hasil_Pemeriksaan_GDP_2
# 0                      0.0                      NaN
# 1                      0.0                      NaN
# 2                      0.0                      NaN
# 3                      0.0                      NaN
# 4                      0.0                      NaN

# %%
df_fktp_n.shape
# Out:
# (1702, 23)

# %%
df_fktp_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1702 entries, 0 to 1701
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nomor_Peserta               1702 non-null   int32
#  1   Nomor_Keluarga              1702 non-null   int32
#  2   Bobot                       1702 non-null   float32
#  3   ID_Kunjungan                1702 non-null   object
#  4   Tanggal_Kunjungan           1702 non-null   datetime64[ns]
#  5   Tanggal_Tindakan            1702 non-null   datetime64[ns]
#  6   Tanggal_Pulang              1702 non-null   datetime64[ns]
#  7   Provinsi_Faskes             1702 non-null   category
#  8   Kode_Kab_Kota_Faskes        1702 non-null   category
#  9   Kepemilikan_Faskes          1702 non-null   category
#  10  Jenis_Faskes                1702 non-null   category
#  11  Tipe_Faskes                 1702 non-null   category
#  12  Tingkat_Layanan             1702 non-null   category
#  13  Segmen_Peserta              1702 non-null   category
#  14  Kode_Nama_Diagnosis_ICD_10  1702 non-null   category
#  15  Kode_Diagnosis_ICD_10       1702 non-null   object
#  16  Kode_Diagnosis_3_5_Digit    1702 non-null   object
#  17  Nama_Diagnosis              1702 non-null   object
#  18  Nama_Tindakan               1702 non-null   category
#  19  Biaya_Tagih                 1702 non-null   int32
#  20  Biaya_Verifikasi            1702 non-null   int32
#  21  Hasil_Pemeriksaan_GDP_1     1394 non-null   float32
#  22  Hasil_Pemeriksaan_GDP_2     1368 non-null   float64
# dtypes: category(9), datetime64[ns](3), float32(2), float64(1), int32(4), object(4)
# memory usage: 187.8+ KB

# %%
df_fktp_n.duplicated().sum()
# Out:
# 0

# %%
df_fktp_n.isna().sum().sum()
# Out:
# 642

# %%
df_fktp_n.isna().sum().tail(2)
# Out:
# Hasil_Pemeriksaan_GDP_1    308
# Hasil_Pemeriksaan_GDP_2    334
# dtype: int64

# %% [markdown]
# ### 1.5. FKRTL Diagnosis Sekunder

# %%
df_fkrtl_2.columns
# Out:
# Index(['FKL02', 'FKL24', 'FKL24A', 'FKL24B'], dtype='object')

# %%
df_fkrtl_2.rename(columns={
    'FKL02' : 'ID_Kunjungan_FKRTL',
    'FKL24' : 'Kode_Diagnosis_3_5_Digit',
    'FKL24A': 'Kode_Diagnosis_ICD_10',
    'FKL24B': 'Kode_Nama_Diagnosis_ICD_10'
}, inplace=True)

# %%
df_fkrtl_2.head()
# Out:
#   ID_Kunjungan_FKRTL Kode_Diagnosis_3_5_Digit Kode_Diagnosis_ICD_10  \
# 0   100080121V000024                     E119                   E11
# 1   100080121V000024                      I10                   I10
# 2   100080121V000024                     I693                   I69
# 3   100080121V000078                     E119                   E11
# 4   100080121V000078                     I693                   I69
#
#                 Kode_Nama_Diagnosis_ICD_10
# 0             E11 Type 2 diabetes mellitus
# 1     I10 Essential (primary) hypertension
# 2  I69 Sequelae of cerebrovascular disease
# 3             E11 Type 2 diabetes mellitus
# 4  I69 Sequelae of cerebrovascular disease

# %%
df_fkrtl_2.shape
# Out:
# (1202910, 4)

# %%
df_fkrtl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1202910 entries, 0 to 1202909
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   ID_Kunjungan_FKRTL          1202910 non-null  object
#  1   Kode_Diagnosis_3_5_Digit    1202910 non-null  object
#  2   Kode_Diagnosis_ICD_10       1202910 non-null  object
#  3   Kode_Nama_Diagnosis_ICD_10  1202910 non-null  object
# dtypes: object(4)
# memory usage: 45.9+ MB

# %%
df_fkrtl_2.duplicated().sum()
# Out:
# 0

# %%
df_fkrtl_2.isna().sum().sum()
# Out:
# 0
